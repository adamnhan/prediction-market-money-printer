# %%
# Cell 1: imports & basic config

from pathlib import Path
import csv
from collections import defaultdict
from typing import List, Dict, Any, Optional

import pandas as pd

from pathlib import Path
import sys

CWD = Path.cwd()
if (CWD / "kalshi_fetcher").exists():
    PROJECT_ROOT = CWD
elif (CWD.parent / "kalshi_fetcher").exists():
    PROJECT_ROOT = CWD.parent
else:
    raise RuntimeError(f"Could not find kalshi_fetcher from {CWD}")

sys.path.append(str(PROJECT_ROOT))

from kalshi_fetcher.kalshi_client import request
print("PROJECT_ROOT =", PROJECT_ROOT)


# Data directories
DATA_DIR = PROJECT_ROOT / "data"
TRADES_DIR = DATA_DIR / "series_trades"

DATA_DIR.mkdir(parents=True, exist_ok=True)
TRADES_DIR.mkdir(parents=True, exist_ok=True)

# 🔧 TODO: fill in your series tickers here
SERIES_TICKERS: List[str] = [
    "kxsbads",
    "kxsongsoncharttswift",
    "kxemmydseries",
    "kxrtcaptainamerica",
    "kxrtmoana2",
    "kxrtmickey17",
    "kxrtsnowwhite",
    "kxrtmufasa",
    "kxrtminecraft",
    "kxsongsoncharttswift2",
    "kxrtthemonkey",
    "kxrtnovocaine",
    "kxrtfantasticfour",
    "kxsongsoncharttswift6",
    "kxtrumpputin",
    "kxllm1-25dec31",
    "kxgameawards-2025",
]

SERIES_TICKERS = [s.upper() for s in SERIES_TICKERS]
print(SERIES_TICKERS)

SERIES_MARKETS_CSV = DATA_DIR / "series_markets.csv"

STATUS_MAP = {
    "closed": "closed",
    "settled": "settled",
    "determined": "closed",   # result known, payouts maybe pending
    "finalized": "settled",   # fully settled
}
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 23
#      19     raise RuntimeError(f"Could not find kalshi_fetcher from {CWD}")
#      21 sys.path.append(str(PROJECT_ROOT))
# ---> 23 from kalshi_fetcher.kalshi_client import request
#      24 print("PROJECT_ROOT =", PROJECT_ROOT)
#      27 # Data directories
#
# File c:\Users\Adam Nhan\prediction-market-money-printer\kalshi_fetcher\kalshi_client.py:4
#       1 # kalshi_fetcher/kalshi_client.py
#       3 import requests
# ----> 4 from config import KALSHI_API_BASE_URL
#       7 def request(endpoint: str, params: dict | None = None) -> dict:
#       8     """
#       9     Make a GET request to the Kalshi API (public endpoints, no auth).
#      10
#    (...)     16         Parsed JSON response as a Python dict.
#      17     """
#
# ModuleNotFoundError: No module named 'config'

# %%
import importlib
import kalshi_fetcher.config as kc
import kalshi_fetcher.kalshi_client as kc_client

kc.KALSHI_API_BASE_URL = "https://api.elections.kalshi.com/marketdata/v2"
importlib.reload(kc_client)  # picks up the updated base URL
# Out:
# <module 'kalshi_fetcher.kalshi_client' from 'c:\\Users\\Adam Nhan\\prediction-market-money-printer\\kalshi_fetcher\\kalshi_client.py'>

# %%
# Cell 2 — Fetch all closed/settled markets for a single series

from typing import Any, Dict, List, Optional

def fetch_markets_for_series(series_ticker: str, limit: int = 1000) -> List[Dict[str, Any]]:
    """
    Fetch ALL closed/settled markets for a given series_ticker.
    Uses your existing kalshi_client.request helper.
    """
    print(f"[series:{series_ticker}] Fetching markets...")
    markets: List[Dict[str, Any]] = []
    cursor: Optional[str] = None

    while True:
        params: Dict[str, Any] = {
            "series_ticker": series_ticker,
            "limit": limit,
            # only want backtestable markets
            "status": "closed,settled",
        }
        if cursor:
            params["cursor"] = cursor

        resp = request("/markets", params=params)
        data = resp


        page_markets = data.get("markets", [])
        markets.extend(page_markets)

        cursor = data.get("cursor")
        if not cursor:
            break

    print(f"[series:{series_ticker}] Found {len(markets)} closed/settled markets.")
    return markets

# %%
# Cell 3 — Fetch markets for ONE series (first in list)

if not SERIES_TICKERS:
    raise ValueError("SERIES_TICKERS is empty — add some tickers in Cell 1.")

test_series = SERIES_TICKERS[0]
print("Testing series:", test_series)

test_markets_raw = fetch_markets_for_series(test_series)

# Show the first few raw dicts
test_markets_raw[:3]
# Out:
# Testing series: KXSBADS
# [series:KXSBADS] Fetching markets...
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[21], line 9
#       6 test_series = SERIES_TICKERS[0]
#       7 print("Testing series:", test_series)
# ----> 9 test_markets_raw = fetch_markets_for_series(test_series)
#      11 # Show the first few raw dicts
#      12 test_markets_raw[:3]
#
# Cell In[20], line 24, in fetch_markets_for_series(series_ticker, limit)
#      21 if cursor:
#      22     params["cursor"] = cursor
# ---> 24 resp = request("/markets", params=params)
#      25 data = resp
#      28 page_markets = data.get("markets", [])
#
# File c:\Users\Adam Nhan\prediction-market-money-printer\kalshi_fetcher\kalshi_client.py:21, in request(endpoint, params)
#      18 url = f"{KALSHI_API_BASE_URL}{endpoint}"
#      20 response = requests.get(url, params=params)
# ---> 21 response.raise_for_status()  # throw if HTTP error
#      23 return response.json()
#
# File c:\Users\Public\anaconda3\envs\prosperity\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://api.elections.kalshi.com/trade-api/v2/markets?series_ticker=KXSBADS&limit=1000&status=closed%2Csettled

# %%
# Cell 4 — Normalize markets for this ONE series into a DataFrame

rows = []

for m in test_markets_raw:
    raw_status = m.get("status")
    normalized_status = STATUS_MAP.get(raw_status, raw_status)

    rows.append({
        "series_ticker": test_series,
        "market_ticker": m.get("ticker"),
        "event_ticker": m.get("event_ticker"),
        "status": raw_status,
        "normalized_status": normalized_status,
        "title": m.get("title"),
        "subtitle": m.get("subtitle"),
        "category": m.get("category"),
        "open_time": m.get("open_time"),
        "close_time": m.get("close_time"),
        "expiration_time": m.get("expiration_time"),
        "settled_time": m.get("settled_time"),
        "yes_bid": m.get("yes_bid"),
        "yes_ask": m.get("yes_ask"),
        "last_price": m.get("last_price"),
        "volume": m.get("volume"),
        "result": m.get("result"),   # "yes" / "no"
    })

test_markets_df = pd.DataFrame(rows)
print("Rows:", len(test_markets_df))
test_markets_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 5
#       1 # Cell 4 — Normalize markets for this ONE series into a DataFrame
#       3 rows = []
# ----> 5 for m in test_markets_raw:
#       6     raw_status = m.get("status")
#       7     normalized_status = STATUS_MAP.get(raw_status, raw_status)
#
# NameError: name 'test_markets_raw' is not defined

# %%
# Cell 5 — Fetch and normalize markets for ALL series tickers

all_markets_rows = []

for series in SERIES_TICKERS:
    print(f"Processing series: {series}")
    
    markets_raw = fetch_markets_for_series(series)
    
    for m in markets_raw:
        raw_status = m.get("status")
        normalized_status = STATUS_MAP.get(raw_status, raw_status)

        all_markets_rows.append({
            "series_ticker": series,
            "market_ticker": m.get("ticker"),
            "event_ticker": m.get("event_ticker"),
            "status": raw_status,
            "normalized_status": normalized_status,
            "title": m.get("title"),
            "subtitle": m.get("subtitle"),
            "category": m.get("category"),
            "open_time": m.get("open_time"),
            "close_time": m.get("close_time"),
            "expiration_time": m.get("expiration_time"),
            "settled_time": m.get("settled_time"),
            "yes_bid": m.get("yes_bid"),
            "yes_ask": m.get("yes_ask"),
            "last_price": m.get("last_price"),
            "volume": m.get("volume"),
            "result": m.get("result"),
        })

series_markets_df = pd.DataFrame(all_markets_rows)

print("Total markets:", len(series_markets_df))
series_markets_df.head()
# Out:
# Processing series: KXSBADS
# [series:KXSBADS] Fetching markets...
# [series:KXSBADS] Found 17 closed/settled markets.
# Processing series: KXSONGSONCHARTTSWIFT
# [series:KXSONGSONCHARTTSWIFT] Fetching markets...
# [series:KXSONGSONCHARTTSWIFT] Found 2 closed/settled markets.
# Processing series: KXEMMYDSERIES
# [series:KXEMMYDSERIES] Fetching markets...
# [series:KXEMMYDSERIES] Found 19 closed/settled markets.
# Processing series: KXRTCAPTAINAMERICA
# [series:KXRTCAPTAINAMERICA] Fetching markets...
# [series:KXRTCAPTAINAMERICA] Found 10 closed/settled markets.
# Processing series: KXRTMOANA2
# [series:KXRTMOANA2] Fetching markets...
# [series:KXRTMOANA2] Found 9 closed/settled markets.
# Processing series: KXRTMICKEY17
# [series:KXRTMICKEY17] Fetching markets...
# [series:KXRTMICKEY17] Found 14 closed/settled markets.
# Processing series: KXRTSNOWWHITE
# [series:KXRTSNOWWHITE] Fetching markets...
# [series:KXRTSNOWWHITE] Found 16 closed/settled markets.
# Processing series: KXRTMUFASA
# [series:KXRTMUFASA] Fetching markets...
# [series:KXRTMUFASA] Found 11 closed/settled markets.
# Processing series: KXRTMINECRAFT
# [series:KXRTMINECRAFT] Fetching markets...
# [series:KXRTMINECRAFT] Found 23 closed/settled markets.
# Processing series: KXSONGSONCHARTTSWIFT2
# [series:KXSONGSONCHARTTSWIFT2] Fetching markets...
# [series:KXSONGSONCHARTTSWIFT2] Found 2 closed/settled markets.
# Processing series: KXRTTHEMONKEY
# [series:KXRTTHEMONKEY] Fetching markets...
# [series:KXRTTHEMONKEY] Found 10 closed/settled markets.
# Processing series: KXRTNOVOCAINE
# [series:KXRTNOVOCAINE] Fetching markets...
# [series:KXRTNOVOCAINE] Found 12 closed/settled markets.
# Processing series: KXRTFANTASTICFOUR
# [series:KXRTFANTASTICFOUR] Fetching markets...
# [series:KXRTFANTASTICFOUR] Found 11 closed/settled markets.
# Processing series: KXSONGSONCHARTTSWIFT6
# [series:KXSONGSONCHARTTSWIFT6] Fetching markets...
# [series:KXSONGSONCHARTTSWIFT6] Found 1 closed/settled markets.
# Processing series: KXTRUMPPUTIN
# [series:KXTRUMPPUTIN] Fetching markets...
# [series:KXTRUMPPUTIN] Found 14 closed/settled markets.
# Total markets: 171
#   series_ticker  market_ticker event_ticker     status normalized_status  \
# 0       KXSBADS  KXSBADS-25-CB   KXSBADS-25  finalized           settled
# 1       KXSBADS   KXSBADS-25-T   KXSBADS-25  finalized           settled
# 2       KXSBADS  KXSBADS-25-PE   KXSBADS-25  finalized           settled
# 3       KXSBADS  KXSBADS-25-CC   KXSBADS-25  finalized           settled
# 4       KXSBADS   KXSBADS-25-H   KXSBADS-25  finalized           settled
#
#                                                title  \
# 0  Will Coinbase Global, Inc. run a Super Bowl ad...
# 1           Will Toyota run a Super Bowl ad in 2025?
# 2            Will Pepsi run a Super Bowl ad in 2025?
# 3        Will Coca-Cola run a Super Bowl ad in 2025?
# 4          Will Hyundai run a Super Bowl ad in 2025?
#
#                                         subtitle category  \
# 0
# 1     :: Includes, for example, Toyota and Lexus
# 2              :: Includes, for example, Doritos
# 3                :: Includes, for example, Fanta
# 4  :: Includes, for example, Hyundai and Genesis
#
#               open_time                   close_time       expiration_time  \
# 0  2025-02-03T22:30:10Z  2025-02-10T03:21:55.832299Z  2025-02-10T15:00:00Z
# 1  2025-01-25T20:00:29Z  2025-02-10T03:23:26.038868Z  2025-02-10T15:00:00Z
# 2  2025-01-25T20:00:26Z  2025-02-10T00:16:05.504161Z  2025-02-10T15:00:00Z
# 3  2025-01-25T20:00:09Z  2025-02-10T03:25:15.623462Z  2025-02-10T15:00:00Z
# 4  2025-01-25T20:00:41Z  2025-02-10T03:23:05.417962Z  2025-02-10T15:00:00Z
#
#   settled_time  yes_bid  yes_ask  last_price  volume result
# 0         None        0        1           1  251537     no
# 1         None        0        1           1  529343     no
# 2         None       99      100          99   97243    yes
# 3         None        0        1           1  673537     no
# 4         None        0        1           9  115213     no

# %%
# Cell 6 — Save markets metadata to data/series_markets.csv

SERIES_MARKETS_CSV = DATA_DIR / "series_markets.csv"

SERIES_MARKETS_CSV.parent.mkdir(parents=True, exist_ok=True)
series_markets_df.to_csv(SERIES_MARKETS_CSV, index=False)

SERIES_MARKETS_CSV
# Out:
# WindowsPath('c:/Users/Adam Nhan/prediction-market-money-printer/data/series_markets.csv')

# %%
# Cell 7 — Unique market tickers across all series

unique_tickers = series_markets_df["market_ticker"].dropna().unique()
len(unique_tickers), unique_tickers[:5]
# Out:
# (171,
#  array(['KXSBADS-25-CB', 'KXSBADS-25-T', 'KXSBADS-25-PE', 'KXSBADS-25-CC',
#         'KXSBADS-25-H'], dtype=object))

# %%
# Cell 8 — Fetch ALL trades for a single market_ticker

def fetch_trades_for_market(ticker: str, limit: int = 1000):
    """
    Fetch ALL public trades for a given market via /markets/trades.
    Uses your request(endpoint, params) helper.
    """
    print(f"[market:{ticker}] Fetching trades...")
    trades = []
    cursor: Optional[str] = None

    while True:
        params: Dict[str, Any] = {
            "ticker": ticker,
            "limit": limit,
        }
        if cursor:
            params["cursor"] = cursor

        data = request("/markets/trades", params=params)

        page_trades = data.get("trades", [])
        trades.extend(page_trades)

        cursor = data.get("cursor")
        if not cursor:
            break

    print(f"[market:{ticker}] Got {len(trades)} trades.")
    return trades

# %%
# Cell 9 — Test fetching trades for a single market

test_ticker = unique_tickers[0]
print("Testing trades for:", test_ticker)

test_trades_raw = fetch_trades_for_market(test_ticker)
len(test_trades_raw), (test_trades_raw[:3] if test_trades_raw else None)
# Out:
# Testing trades for: KXSBADS-25-CB
# [market:KXSBADS-25-CB] Fetching trades...
# [market:KXSBADS-25-CB] Got 4290 trades.
# (4290,
#  [{'count': 4193,
#    'created_time': '2025-02-10T03:20:57.509561Z',
#    'no_price': 99,
#    'no_price_dollars': '0.9900',
#    'price': 0.01,
#    'taker_side': 'yes',
#    'ticker': 'KXSBADS-25-CB',
#    'trade_id': 'c17edfc1-b778-4261-bf9b-d6517493dbb0',
#    'yes_price': 1,
#    'yes_price_dollars': '0.0100'},
#   {'count': 1000,
#    'created_time': '2025-02-10T03:20:16.115251Z',
#    'no_price': 99,
#    'no_price_dollars': '0.9900',
#    'price': 0.01,
#    'taker_side': 'yes',
#    'ticker': 'KXSBADS-25-CB',
#    'trade_id': 'bafc053e-9981-455b-8ba7-4b80c5b39d52',
#    'yes_price': 1,
#    'yes_price_dollars': '0.0100'},
#   {'count': 500,
#    'created_time': '2025-02-10T03:20:16.115251Z',
#    'no_price': 99,
#    'no_price_dollars': '0.9900',
#    'price': 0.01,
#    'taker_side': 'yes',
#    'ticker': 'KXSBADS-25-CB',
#    'trade_id': '85341570-95e0-464e-af4b-dcbdb5128cab',
#    'yes_price': 1,
#    'yes_price_dollars': '0.0100'}])

# %%
# Cell 10 — Save trades for a single market to data/series_trades/{ticker}.csv

def save_trades_csv(ticker: str, trades: list) -> Path:
    """
    Save trades for a market to data/series_trades/{ticker}.csv
    using a consistent subset of fields.
    """
    out_path = TRADES_DIR / f"{ticker}.csv"

    if not trades:
        print(f"[market:{ticker}] No trades, skipping write.")
        return out_path

    # Fields useful for Δp / intraday backtesting
    fieldnames = [
        "trade_id",
        "ticker",
        "price",               # cents
        "yes_price",
        "no_price",
        "yes_price_dollars",   # already /100
        "no_price_dollars",
        "count",
        "taker_side",
        "created_time",
    ]

    with out_path.open("w", newline="") as f:
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()
        for t in trades:
            row = {k: t.get(k) for k in fieldnames}
            writer.writerow(row)

    print(f"[market:{ticker}] Wrote {len(trades)} trades to {out_path}")
    return out_path

# %%
# Cell 11 — Save trades for ONE test market

test_ticker = unique_tickers[0]
print("Saving trades for:", test_ticker)

_ = save_trades_csv(test_ticker, test_trades_raw)

# Confirm file exists
(TRADES_DIR / f"{test_ticker}.csv").exists()
# Out:
# Saving trades for: KXSBADS-25-CB
# [market:KXSBADS-25-CB] Wrote 4290 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXSBADS-25-CB.csv
# True

# %%
# Cell 12 — Fetch and save trades for ALL markets in series_markets_df

for ticker in unique_tickers:
    print("=" * 60)
    print("Processing ticker:", ticker)

    trades = fetch_trades_for_market(ticker)
    save_trades_csv(ticker, trades)

print("Done fetching & saving trades for all tickers.")
# Out:
# ============================================================
# Processing ticker: KXSBADS-25-CB
# [market:KXSBADS-25-CB] Fetching trades...
# [market:KXSBADS-25-CB] Got 4290 trades.
# [market:KXSBADS-25-CB] Wrote 4290 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXSBADS-25-CB.csv
# ============================================================
# Processing ticker: KXSBADS-25-T
# [market:KXSBADS-25-T] Fetching trades...
# [market:KXSBADS-25-T] Got 4930 trades.
# [market:KXSBADS-25-T] Wrote 4930 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXSBADS-25-T.csv
# ============================================================
# Processing ticker: KXSBADS-25-PE
# [market:KXSBADS-25-PE] Fetching trades...
# [market:KXSBADS-25-PE] Got 166 trades.
# [market:KXSBADS-25-PE] Wrote 166 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXSBADS-25-PE.csv
# ============================================================
# Processing ticker: KXSBADS-25-CC
# [market:KXSBADS-25-CC] Fetching trades...
# [market:KXSBADS-25-CC] Got 11864 trades.
# [market:KXSBADS-25-CC] Wrote 11864 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXSBADS-25-CC.csv
# ============================================================
# Processing ticker: KXSBADS-25-H
# [market:KXSBADS-25-H] Fetching trades...
# [market:KXSBADS-25-H] Got 1447 trades.
# [market:KXSBADS-25-H] Wrote 1447 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXSBADS-25-H.csv
# ============================================================
# Processing ticker: KXSBADS-25-AP
# [market:KXSBADS-25-AP] Fetching trades...
# [market:KXSBADS-25-AP] Got 8309 trades.
# [market:KXSBADS-25-AP] Wrote 8309 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXSBADS-25-AP.csv
# ============================================================
# Processing ticker: KXSBADS-25-B
# [market:KXSBADS-25-B] Fetching trades...
# [market:KXSBADS-25-B] Got 2656 trades.
# [market:KXSBADS-25-B] Wrote 2656 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXSBADS-25-B.csv
# ============================================================
# Processing ticker: KXSBADS-25-N
# [market:KXSBADS-25-N] Fetching trades...
# [market:KXSBADS-25-N] Got 1459 trades.
# [market:KXSBADS-25-N] Wrote 1459 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXSBADS-25-N.csv
# ============================================================
# Processing ticker: KXSBADS-25-SF
# [market:KXSBADS-25-SF] Fetching trades...
# [market:KXSBADS-25-SF] Got 7288 trades.
# [market:KXSBADS-25-SF] Wrote 7288 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXSBADS-25-SF.csv
# ============================================================
# Processing ticker: KXSBADS-25-V
# [market:KXSBADS-25-V] Fetching trades...
# [market:KXSBADS-25-V] Got 8340 trades.
# [market:KXSBADS-25-V] Wrote 8340 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXSBADS-25-V.csv
# ============================================================
# Processing ticker: KXSBADS-25-TM
# [market:KXSBADS-25-TM] Fetching trades...
# [market:KXSBADS-25-TM] Got 6227 trades.
# [market:KXSBADS-25-TM] Wrote 6227 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXSBADS-25-TM.csv
# ============================================================
# Processing ticker: KXSBADS-25-PR
# [market:KXSBADS-25-PR] Fetching trades...
# [market:KXSBADS-25-PR] Got 2725 trades.
# [market:KXSBADS-25-PR] Wrote 2725 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXSBADS-25-PR.csv
# ============================================================
# Processing ticker: KXSBADS-25-FD
# [market:KXSBADS-25-FD] Fetching trades...
# [market:KXSBADS-25-FD] Got 983 trades.
# [market:KXSBADS-25-FD] Wrote 983 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXSBADS-25-FD.csv
# ============================================================
# Processing ticker: KXSBADS-25-XAI
# [market:KXSBADS-25-XAI] Fetching trades...
# [market:KXSBADS-25-XAI] Got 1019 trades.
# [market:KXSBADS-25-XAI] Wrote 1019 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXSBADS-25-XAI.csv
# ============================================================
# Processing ticker: KXSBADS-25-P
# [market:KXSBADS-25-P] Fetching trades...
# [market:KXSBADS-25-P] Got 3256 trades.
# [market:KXSBADS-25-P] Wrote 3256 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXSBADS-25-P.csv
# ============================================================
# Processing ticker: KXSBADS-25-OAI
# [market:KXSBADS-25-OAI] Fetching trades...
# [market:KXSBADS-25-OAI] Got 3712 trades.
# [market:KXSBADS-25-OAI] Wrote 3712 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXSBADS-25-OAI.csv
# ============================================================
# Processing ticker: KXSBADS-25-A
# [market:KXSBADS-25-A] Fetching trades...
# [market:KXSBADS-25-A] Got 1642 trades.
# [market:KXSBADS-25-A] Wrote 1642 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXSBADS-25-A.csv
# ============================================================
# Processing ticker: KXSONGSONCHARTTSWIFT-25OCT25
# [market:KXSONGSONCHARTTSWIFT-25OCT25] Fetching trades...
# [market:KXSONGSONCHARTTSWIFT-25OCT25] Got 378 trades.
# [market:KXSONGSONCHARTTSWIFT-25OCT25] Wrote 378 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXSONGSONCHARTTSWIFT-25OCT25.csv
# ============================================================
# Processing ticker: KXSONGSONCHARTTSWIFT-25OCT18
# [market:KXSONGSONCHARTTSWIFT-25OCT18] Fetching trades...
# [market:KXSONGSONCHARTTSWIFT-25OCT18] Got 11133 trades.
# [market:KXSONGSONCHARTTSWIFT-25OCT18] Wrote 11133 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXSONGSONCHARTTSWIFT-25OCT18.csv
# ============================================================
# Processing ticker: KXEMMYDSERIES-77-TIE
# [market:KXEMMYDSERIES-77-TIE] Fetching trades...
# [market:KXEMMYDSERIES-77-TIE] Got 60 trades.
# [market:KXEMMYDSERIES-77-TIE] Wrote 60 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXEMMYDSERIES-77-TIE.csv
# ============================================================
# Processing ticker: KXEMMYDSERIES-77-SQU
# [market:KXEMMYDSERIES-77-SQU] Fetching trades...
# [market:KXEMMYDSERIES-77-SQU] Got 23 trades.
# [market:KXEMMYDSERIES-77-SQU] Wrote 23 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXEMMYDSERIES-77-SQU.csv
# ============================================================
# Processing ticker: KXEMMYDSERIES-77-PAR
# [market:KXEMMYDSERIES-77-PAR] Fetching trades...
# [market:KXEMMYDSERIES-77-PAR] Got 92 trades.
# [market:KXEMMYDSERIES-77-PAR] Wrote 92 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXEMMYDSERIES-77-PAR.csv
# ============================================================
# Processing ticker: KXEMMYDSERIES-77-HAN
# [market:KXEMMYDSERIES-77-HAN] Fetching trades...
# [market:KXEMMYDSERIES-77-HAN] Got 15 trades.
# [market:KXEMMYDSERIES-77-HAN] Wrote 15 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXEMMYDSERIES-77-HAN.csv
# ============================================================
# Processing ticker: KXEMMYDSERIES-77-DIP
# [market:KXEMMYDSERIES-77-DIP] Fetching trades...
# [market:KXEMMYDSERIES-77-DIP] Got 90 trades.
# [market:KXEMMYDSERIES-77-DIP] Wrote 90 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXEMMYDSERIES-77-DIP.csv
# ============================================================
# Processing ticker: KXEMMYDSERIES-77-AND
# [market:KXEMMYDSERIES-77-AND] Fetching trades...
# [market:KXEMMYDSERIES-77-AND] Got 1357 trades.
# [market:KXEMMYDSERIES-77-AND] Wrote 1357 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXEMMYDSERIES-77-AND.csv
# ============================================================
# Processing ticker: KXEMMYDSERIES-77-WHI
# [market:KXEMMYDSERIES-77-WHI] Fetching trades...
# [market:KXEMMYDSERIES-77-WHI] Got 573 trades.
# [market:KXEMMYDSERIES-77-WHI] Wrote 573 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXEMMYDSERIES-77-WHI.csv
# ============================================================
# Processing ticker: KXEMMYDSERIES-77-SLO
# [market:KXEMMYDSERIES-77-SLO] Fetching trades...
# [market:KXEMMYDSERIES-77-SLO] Got 133 trades.
# [market:KXEMMYDSERIES-77-SLO] Wrote 133 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXEMMYDSERIES-77-SLO.csv
# ============================================================
# Processing ticker: KXEMMYDSERIES-77-SEV
# [market:KXEMMYDSERIES-77-SEV] Fetching trades...
# [market:KXEMMYDSERIES-77-SEV] Got 8553 trades.
# [market:KXEMMYDSERIES-77-SEV] Wrote 8553 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXEMMYDSERIES-77-SEV.csv
# ============================================================
# Processing ticker: KXEMMYDSERIES-77-PIT
# [market:KXEMMYDSERIES-77-PIT] Fetching trades...
# [market:KXEMMYDSERIES-77-PIT] Got 3251 trades.
# [market:KXEMMYDSERIES-77-PIT] Wrote 3251 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXEMMYDSERIES-77-PIT.csv
# ============================================================
# Processing ticker: KXEMMYDSERIES-77-LAS
# [market:KXEMMYDSERIES-77-LAS] Fetching trades...
# [market:KXEMMYDSERIES-77-LAS] Got 318 trades.
# [market:KXEMMYDSERIES-77-LAS] Wrote 318 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXEMMYDSERIES-77-LAS.csv
# ============================================================
# Processing ticker: EMMYDSERIES-23-Y
# [market:EMMYDSERIES-23-Y] Fetching trades...
# [market:EMMYDSERIES-23-Y] Got 1 trades.
# [market:EMMYDSERIES-23-Y] Wrote 1 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\EMMYDSERIES-23-Y.csv
# ============================================================
# Processing ticker: EMMYDSERIES-23-TWL
# [market:EMMYDSERIES-23-TWL] Fetching trades...
# [market:EMMYDSERIES-23-TWL] Got 25 trades.
# [market:EMMYDSERIES-23-TWL] Wrote 25 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\EMMYDSERIES-23-TWL.csv
# ============================================================
# Processing ticker: EMMYDSERIES-23-S
# [market:EMMYDSERIES-23-S] Fetching trades...
# [market:EMMYDSERIES-23-S] Got 116 trades.
# [market:EMMYDSERIES-23-S] Wrote 116 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\EMMYDSERIES-23-S.csv
# ============================================================
# Processing ticker: EMMYDSERIES-23-TLOU
# [market:EMMYDSERIES-23-TLOU] Fetching trades...
# [market:EMMYDSERIES-23-TLOU] Got 32 trades.
# [market:EMMYDSERIES-23-TLOU] Wrote 32 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\EMMYDSERIES-23-TLOU.csv
# ============================================================
# Processing ticker: EMMYDSERIES-23-TC
# [market:EMMYDSERIES-23-TC] Fetching trades...
# [market:EMMYDSERIES-23-TC] Got 0 trades.
# [market:EMMYDSERIES-23-TC] No trades, skipping write.
# ============================================================
# Processing ticker: EMMYDSERIES-23-HOTD
# [market:EMMYDSERIES-23-HOTD] Fetching trades...
# [market:EMMYDSERIES-23-HOTD] Got 0 trades.
# [market:EMMYDSERIES-23-HOTD] No trades, skipping write.
# ============================================================
# Processing ticker: EMMYDSERIES-23-BCS
# [market:EMMYDSERIES-23-BCS] Fetching trades...
# [market:EMMYDSERIES-23-BCS] Got 25 trades.
# [market:EMMYDSERIES-23-BCS] Wrote 25 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\EMMYDSERIES-23-BCS.csv
# ============================================================
# Processing ticker: EMMYDSERIES-23-A
# [market:EMMYDSERIES-23-A] Fetching trades...
# [market:EMMYDSERIES-23-A] Got 0 trades.
# [market:EMMYDSERIES-23-A] No trades, skipping write.
# ============================================================
# Processing ticker: KXRTCAPTAINAMERICA-48
# [market:KXRTCAPTAINAMERICA-48] Fetching trades...
# [market:KXRTCAPTAINAMERICA-48] Got 369 trades.
# [market:KXRTCAPTAINAMERICA-48] Wrote 369 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTCAPTAINAMERICA-48.csv
# ============================================================
# Processing ticker: KXRTCAPTAINAMERICA-80
# [market:KXRTCAPTAINAMERICA-80] Fetching trades...
# [market:KXRTCAPTAINAMERICA-80] Got 295 trades.
# [market:KXRTCAPTAINAMERICA-80] Wrote 295 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTCAPTAINAMERICA-80.csv
# ============================================================
# Processing ticker: KXRTCAPTAINAMERICA-70
# [market:KXRTCAPTAINAMERICA-70] Fetching trades...
# [market:KXRTCAPTAINAMERICA-70] Got 728 trades.
# [market:KXRTCAPTAINAMERICA-70] Wrote 728 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTCAPTAINAMERICA-70.csv
# ============================================================
# Processing ticker: KXRTCAPTAINAMERICA-65
# [market:KXRTCAPTAINAMERICA-65] Fetching trades...
# [market:KXRTCAPTAINAMERICA-65] Got 842 trades.
# [market:KXRTCAPTAINAMERICA-65] Wrote 842 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTCAPTAINAMERICA-65.csv
# ============================================================
# Processing ticker: KXRTCAPTAINAMERICA-55
# [market:KXRTCAPTAINAMERICA-55] Fetching trades...
# [market:KXRTCAPTAINAMERICA-55] Got 1665 trades.
# [market:KXRTCAPTAINAMERICA-55] Wrote 1665 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTCAPTAINAMERICA-55.csv
# ============================================================
# Processing ticker: KXRTCAPTAINAMERICA-50
# [market:KXRTCAPTAINAMERICA-50] Fetching trades...
# [market:KXRTCAPTAINAMERICA-50] Got 6698 trades.
# [market:KXRTCAPTAINAMERICA-50] Wrote 6698 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTCAPTAINAMERICA-50.csv
# ============================================================
# Processing ticker: KXRTCAPTAINAMERICA-90
# [market:KXRTCAPTAINAMERICA-90] Fetching trades...
# [market:KXRTCAPTAINAMERICA-90] Got 195 trades.
# [market:KXRTCAPTAINAMERICA-90] Wrote 195 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTCAPTAINAMERICA-90.csv
# ============================================================
# Processing ticker: KXRTCAPTAINAMERICA-75
# [market:KXRTCAPTAINAMERICA-75] Fetching trades...
# [market:KXRTCAPTAINAMERICA-75] Got 1137 trades.
# [market:KXRTCAPTAINAMERICA-75] Wrote 1137 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTCAPTAINAMERICA-75.csv
# ============================================================
# Processing ticker: KXRTCAPTAINAMERICA-60
# [market:KXRTCAPTAINAMERICA-60] Fetching trades...
# [market:KXRTCAPTAINAMERICA-60] Got 1657 trades.
# [market:KXRTCAPTAINAMERICA-60] Wrote 1657 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTCAPTAINAMERICA-60.csv
# ============================================================
# Processing ticker: KXRTCAPTAINAMERICA-45
# [market:KXRTCAPTAINAMERICA-45] Fetching trades...
# [market:KXRTCAPTAINAMERICA-45] Got 1893 trades.
# [market:KXRTCAPTAINAMERICA-45] Wrote 1893 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTCAPTAINAMERICA-45.csv
# ============================================================
# Processing ticker: KXRTMOANA2-70
# [market:KXRTMOANA2-70] Fetching trades...
# [market:KXRTMOANA2-70] Got 1276 trades.
# [market:KXRTMOANA2-70] Wrote 1276 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMOANA2-70.csv
# ============================================================
# Processing ticker: KXRTMOANA2-65
# [market:KXRTMOANA2-65] Fetching trades...
# [market:KXRTMOANA2-65] Got 2447 trades.
# [market:KXRTMOANA2-65] Wrote 2447 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMOANA2-65.csv
# ============================================================
# Processing ticker: KXRTMOANA2-95
# [market:KXRTMOANA2-95] Fetching trades...
# [market:KXRTMOANA2-95] Got 271 trades.
# [market:KXRTMOANA2-95] Wrote 271 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMOANA2-95.csv
# ============================================================
# Processing ticker: KXRTMOANA2-85
# [market:KXRTMOANA2-85] Fetching trades...
# [market:KXRTMOANA2-85] Got 1083 trades.
# [market:KXRTMOANA2-85] Wrote 1083 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMOANA2-85.csv
# ============================================================
# Processing ticker: KXRTMOANA2-80
# [market:KXRTMOANA2-80] Fetching trades...
# [market:KXRTMOANA2-80] Got 1129 trades.
# [market:KXRTMOANA2-80] Wrote 1129 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMOANA2-80.csv
# ============================================================
# Processing ticker: KXRTMOANA2-90
# [market:KXRTMOANA2-90] Fetching trades...
# [market:KXRTMOANA2-90] Got 828 trades.
# [market:KXRTMOANA2-90] Wrote 828 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMOANA2-90.csv
# ============================================================
# Processing ticker: KXRTMOANA2-75
# [market:KXRTMOANA2-75] Fetching trades...
# [market:KXRTMOANA2-75] Got 1236 trades.
# [market:KXRTMOANA2-75] Wrote 1236 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMOANA2-75.csv
# ============================================================
# Processing ticker: KXRTMOANA2-60
# [market:KXRTMOANA2-60] Fetching trades...
# [market:KXRTMOANA2-60] Got 947 trades.
# [market:KXRTMOANA2-60] Wrote 947 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMOANA2-60.csv
# ============================================================
# Processing ticker: KXRTMOANA2-45
# [market:KXRTMOANA2-45] Fetching trades...
# [market:KXRTMOANA2-45] Got 101 trades.
# [market:KXRTMOANA2-45] Wrote 101 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMOANA2-45.csv
# ============================================================
# Processing ticker: KXRTMICKEY17-78
# [market:KXRTMICKEY17-78] Fetching trades...
# [market:KXRTMICKEY17-78] Got 2176 trades.
# [market:KXRTMICKEY17-78] Wrote 2176 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMICKEY17-78.csv
# ============================================================
# Processing ticker: KXRTMICKEY17-87
# [market:KXRTMICKEY17-87] Fetching trades...
# [market:KXRTMICKEY17-87] Got 2063 trades.
# [market:KXRTMICKEY17-87] Wrote 2063 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMICKEY17-87.csv
# ============================================================
# Processing ticker: KXRTMICKEY17-82
# [market:KXRTMICKEY17-82] Fetching trades...
# [market:KXRTMICKEY17-82] Got 4798 trades.
# [market:KXRTMICKEY17-82] Wrote 4798 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMICKEY17-82.csv
# ============================================================
# Processing ticker: KXRTMICKEY17-95
# [market:KXRTMICKEY17-95] Fetching trades...
# [market:KXRTMICKEY17-95] Got 318 trades.
# [market:KXRTMICKEY17-95] Wrote 318 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMICKEY17-95.csv
# ============================================================
# Processing ticker: KXRTMICKEY17-90
# [market:KXRTMICKEY17-90] Fetching trades...
# [market:KXRTMICKEY17-90] Got 2625 trades.
# [market:KXRTMICKEY17-90] Wrote 2625 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMICKEY17-90.csv
# ============================================================
# Processing ticker: KXRTMICKEY17-85
# [market:KXRTMICKEY17-85] Fetching trades...
# [market:KXRTMICKEY17-85] Got 5836 trades.
# [market:KXRTMICKEY17-85] Wrote 5836 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMICKEY17-85.csv
# ============================================================
# Processing ticker: KXRTMICKEY17-80
# [market:KXRTMICKEY17-80] Fetching trades...
# [market:KXRTMICKEY17-80] Got 5755 trades.
# [market:KXRTMICKEY17-80] Wrote 5755 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMICKEY17-80.csv
# ============================================================
# Processing ticker: KXRTMICKEY17-75
# [market:KXRTMICKEY17-75] Fetching trades...
# [market:KXRTMICKEY17-75] Got 2100 trades.
# [market:KXRTMICKEY17-75] Wrote 2100 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMICKEY17-75.csv
# ============================================================
# Processing ticker: KXRTMICKEY17-70
# [market:KXRTMICKEY17-70] Fetching trades...
# [market:KXRTMICKEY17-70] Got 86 trades.
# [market:KXRTMICKEY17-70] Wrote 86 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMICKEY17-70.csv
# ============================================================
# Processing ticker: KXRTMICKEY17-65
# [market:KXRTMICKEY17-65] Fetching trades...
# [market:KXRTMICKEY17-65] Got 32 trades.
# [market:KXRTMICKEY17-65] Wrote 32 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMICKEY17-65.csv
# ============================================================
# Processing ticker: KXRTMICKEY17-60
# [market:KXRTMICKEY17-60] Fetching trades...
# [market:KXRTMICKEY17-60] Got 11 trades.
# [market:KXRTMICKEY17-60] Wrote 11 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMICKEY17-60.csv
# ============================================================
# Processing ticker: KXRTMICKEY17-55
# [market:KXRTMICKEY17-55] Fetching trades...
# [market:KXRTMICKEY17-55] Got 2 trades.
# [market:KXRTMICKEY17-55] Wrote 2 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMICKEY17-55.csv
# ============================================================
# Processing ticker: KXRTMICKEY17-50
# [market:KXRTMICKEY17-50] Fetching trades...
# [market:KXRTMICKEY17-50] Got 3 trades.
# [market:KXRTMICKEY17-50] Wrote 3 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMICKEY17-50.csv
# ============================================================
# Processing ticker: KXRTMICKEY17-45
# [market:KXRTMICKEY17-45] Fetching trades...
# [market:KXRTMICKEY17-45] Got 5 trades.
# [market:KXRTMICKEY17-45] Wrote 5 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMICKEY17-45.csv
# ============================================================
# Processing ticker: KXRTSNOWWHITE-43
# [market:KXRTSNOWWHITE-43] Fetching trades...
# [market:KXRTSNOWWHITE-43] Got 1648 trades.
# [market:KXRTSNOWWHITE-43] Wrote 1648 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTSNOWWHITE-43.csv
# ============================================================
# Processing ticker: KXRTSNOWWHITE-48
# [market:KXRTSNOWWHITE-48] Fetching trades...
# [market:KXRTSNOWWHITE-48] Got 153 trades.
# [market:KXRTSNOWWHITE-48] Wrote 153 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTSNOWWHITE-48.csv
# ============================================================
# Processing ticker: KXRTSNOWWHITE-15
# [market:KXRTSNOWWHITE-15] Fetching trades...
# [market:KXRTSNOWWHITE-15] Got 3 trades.
# [market:KXRTSNOWWHITE-15] Wrote 3 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTSNOWWHITE-15.csv
# ============================================================
# Processing ticker: KXRTSNOWWHITE-70
# [market:KXRTSNOWWHITE-70] Fetching trades...
# [market:KXRTSNOWWHITE-70] Got 211 trades.
# [market:KXRTSNOWWHITE-70] Wrote 211 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTSNOWWHITE-70.csv
# ============================================================
# Processing ticker: KXRTSNOWWHITE-20
# [market:KXRTSNOWWHITE-20] Fetching trades...
# [market:KXRTSNOWWHITE-20] Got 49 trades.
# [market:KXRTSNOWWHITE-20] Wrote 49 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTSNOWWHITE-20.csv
# ============================================================
# Processing ticker: KXRTSNOWWHITE-25
# [market:KXRTSNOWWHITE-25] Fetching trades...
# [market:KXRTSNOWWHITE-25] Got 89 trades.
# [market:KXRTSNOWWHITE-25] Wrote 89 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTSNOWWHITE-25.csv
# ============================================================
# Processing ticker: KXRTSNOWWHITE-65
# [market:KXRTSNOWWHITE-65] Fetching trades...
# [market:KXRTSNOWWHITE-65] Got 508 trades.
# [market:KXRTSNOWWHITE-65] Wrote 508 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTSNOWWHITE-65.csv
# ============================================================
# Processing ticker: KXRTSNOWWHITE-55
# [market:KXRTSNOWWHITE-55] Fetching trades...
# [market:KXRTSNOWWHITE-55] Got 989 trades.
# [market:KXRTSNOWWHITE-55] Wrote 989 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTSNOWWHITE-55.csv
# ============================================================
# Processing ticker: KXRTSNOWWHITE-40
# [market:KXRTSNOWWHITE-40] Fetching trades...
# [market:KXRTSNOWWHITE-40] Got 1466 trades.
# [market:KXRTSNOWWHITE-40] Wrote 1466 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTSNOWWHITE-40.csv
# ============================================================
# Processing ticker: KXRTSNOWWHITE-35
# [market:KXRTSNOWWHITE-35] Fetching trades...
# [market:KXRTSNOWWHITE-35] Got 448 trades.
# [market:KXRTSNOWWHITE-35] Wrote 448 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTSNOWWHITE-35.csv
# ============================================================
# Processing ticker: KXRTSNOWWHITE-30
# [market:KXRTSNOWWHITE-30] Fetching trades...
# [market:KXRTSNOWWHITE-30] Got 160 trades.
# [market:KXRTSNOWWHITE-30] Wrote 160 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTSNOWWHITE-30.csv
# ============================================================
# Processing ticker: KXRTSNOWWHITE-50
# [market:KXRTSNOWWHITE-50] Fetching trades...
# [market:KXRTSNOWWHITE-50] Got 3703 trades.
# [market:KXRTSNOWWHITE-50] Wrote 3703 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTSNOWWHITE-50.csv
# ============================================================
# Processing ticker: KXRTSNOWWHITE-90
# [market:KXRTSNOWWHITE-90] Fetching trades...
# [market:KXRTSNOWWHITE-90] Got 132 trades.
# [market:KXRTSNOWWHITE-90] Wrote 132 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTSNOWWHITE-90.csv
# ============================================================
# Processing ticker: KXRTSNOWWHITE-75
# [market:KXRTSNOWWHITE-75] Fetching trades...
# [market:KXRTSNOWWHITE-75] Got 730 trades.
# [market:KXRTSNOWWHITE-75] Wrote 730 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTSNOWWHITE-75.csv
# ============================================================
# Processing ticker: KXRTSNOWWHITE-60
# [market:KXRTSNOWWHITE-60] Fetching trades...
# [market:KXRTSNOWWHITE-60] Got 2623 trades.
# [market:KXRTSNOWWHITE-60] Wrote 2623 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTSNOWWHITE-60.csv
# ============================================================
# Processing ticker: KXRTSNOWWHITE-45
# [market:KXRTSNOWWHITE-45] Fetching trades...
# [market:KXRTSNOWWHITE-45] Got 4271 trades.
# [market:KXRTSNOWWHITE-45] Wrote 4271 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTSNOWWHITE-45.csv
# ============================================================
# Processing ticker: KXRTMUFASA-57
# [market:KXRTMUFASA-57] Fetching trades...
# [market:KXRTMUFASA-57] Got 577 trades.
# [market:KXRTMUFASA-57] Wrote 577 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMUFASA-57.csv
# ============================================================
# Processing ticker: KXRTMUFASA-85
# [market:KXRTMUFASA-85] Fetching trades...
# [market:KXRTMUFASA-85] Got 41 trades.
# [market:KXRTMUFASA-85] Wrote 41 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMUFASA-85.csv
# ============================================================
# Processing ticker: KXRTMUFASA-80
# [market:KXRTMUFASA-80] Fetching trades...
# [market:KXRTMUFASA-80] Got 105 trades.
# [market:KXRTMUFASA-80] Wrote 105 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMUFASA-80.csv
# ============================================================
# Processing ticker: KXRTMUFASA-70
# [market:KXRTMUFASA-70] Fetching trades...
# [market:KXRTMUFASA-70] Got 507 trades.
# [market:KXRTMUFASA-70] Wrote 507 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMUFASA-70.csv
# ============================================================
# Processing ticker: KXRTMUFASA-65
# [market:KXRTMUFASA-65] Fetching trades...
# [market:KXRTMUFASA-65] Got 776 trades.
# [market:KXRTMUFASA-65] Wrote 776 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMUFASA-65.csv
# ============================================================
# Processing ticker: KXRTMUFASA-55
# [market:KXRTMUFASA-55] Fetching trades...
# [market:KXRTMUFASA-55] Got 2331 trades.
# [market:KXRTMUFASA-55] Wrote 2331 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMUFASA-55.csv
# ============================================================
# Processing ticker: KXRTMUFASA-50
# [market:KXRTMUFASA-50] Fetching trades...
# [market:KXRTMUFASA-50] Got 626 trades.
# [market:KXRTMUFASA-50] Wrote 626 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMUFASA-50.csv
# ============================================================
# Processing ticker: KXRTMUFASA-90
# [market:KXRTMUFASA-90] Fetching trades...
# [market:KXRTMUFASA-90] Got 192 trades.
# [market:KXRTMUFASA-90] Wrote 192 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMUFASA-90.csv
# ============================================================
# Processing ticker: KXRTMUFASA-75
# [market:KXRTMUFASA-75] Fetching trades...
# [market:KXRTMUFASA-75] Got 588 trades.
# [market:KXRTMUFASA-75] Wrote 588 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMUFASA-75.csv
# ============================================================
# Processing ticker: KXRTMUFASA-60
# [market:KXRTMUFASA-60] Fetching trades...
# [market:KXRTMUFASA-60] Got 1687 trades.
# [market:KXRTMUFASA-60] Wrote 1687 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMUFASA-60.csv
# ============================================================
# Processing ticker: KXRTMUFASA-45
# [market:KXRTMUFASA-45] Fetching trades...
# [market:KXRTMUFASA-45] Got 357 trades.
# [market:KXRTMUFASA-45] Wrote 357 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMUFASA-45.csv
# ============================================================
# Processing ticker: KXRTMINECRAFT-48
# [market:KXRTMINECRAFT-48] Fetching trades...
# [market:KXRTMINECRAFT-48] Got 1564 trades.
# [market:KXRTMINECRAFT-48] Wrote 1564 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMINECRAFT-48.csv
# ============================================================
# Processing ticker: KXRTMINECRAFT-57
# [market:KXRTMINECRAFT-57] Fetching trades...
# [market:KXRTMINECRAFT-57] Got 59 trades.
# [market:KXRTMINECRAFT-57] Wrote 59 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMINECRAFT-57.csv
# ============================================================
# Processing ticker: KXRTMINECRAFT-52
# [market:KXRTMINECRAFT-52] Fetching trades...
# [market:KXRTMINECRAFT-52] Got 553 trades.
# [market:KXRTMINECRAFT-52] Wrote 553 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMINECRAFT-52.csv
# ============================================================
# Processing ticker: KXRTMINECRAFT-95
# [market:KXRTMINECRAFT-95] Fetching trades...
# [market:KXRTMINECRAFT-95] Got 1 trades.
# [market:KXRTMINECRAFT-95] Wrote 1 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMINECRAFT-95.csv
# ============================================================
# Processing ticker: KXRTMINECRAFT-0
# [market:KXRTMINECRAFT-0] Fetching trades...
# [market:KXRTMINECRAFT-0] Got 4 trades.
# [market:KXRTMINECRAFT-0] Wrote 4 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMINECRAFT-0.csv
# ============================================================
# Processing ticker: KXRTMINECRAFT-40
# [market:KXRTMINECRAFT-40] Fetching trades...
# [market:KXRTMINECRAFT-40] Got 2476 trades.
# [market:KXRTMINECRAFT-40] Wrote 2476 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMINECRAFT-40.csv
# ============================================================
# Processing ticker: KXRTMINECRAFT-35
# [market:KXRTMINECRAFT-35] Fetching trades...
# [market:KXRTMINECRAFT-35] Got 913 trades.
# [market:KXRTMINECRAFT-35] Wrote 913 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMINECRAFT-35.csv
# ============================================================
# Processing ticker: KXRTMINECRAFT-30
# [market:KXRTMINECRAFT-30] Fetching trades...
# [market:KXRTMINECRAFT-30] Got 549 trades.
# [market:KXRTMINECRAFT-30] Wrote 549 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMINECRAFT-30.csv
# ============================================================
# Processing ticker: KXRTMINECRAFT-25
# [market:KXRTMINECRAFT-25] Fetching trades...
# [market:KXRTMINECRAFT-25] Got 468 trades.
# [market:KXRTMINECRAFT-25] Wrote 468 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMINECRAFT-25.csv
# ============================================================
# Processing ticker: KXRTMINECRAFT-20
# [market:KXRTMINECRAFT-20] Fetching trades...
# [market:KXRTMINECRAFT-20] Got 120 trades.
# [market:KXRTMINECRAFT-20] Wrote 120 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMINECRAFT-20.csv
# ============================================================
# Processing ticker: KXRTMINECRAFT-15
# [market:KXRTMINECRAFT-15] Fetching trades...
# [market:KXRTMINECRAFT-15] Got 66 trades.
# [market:KXRTMINECRAFT-15] Wrote 66 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMINECRAFT-15.csv
# ============================================================
# Processing ticker: KXRTMINECRAFT-10
# [market:KXRTMINECRAFT-10] Fetching trades...
# [market:KXRTMINECRAFT-10] Got 16 trades.
# [market:KXRTMINECRAFT-10] Wrote 16 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMINECRAFT-10.csv
# ============================================================
# Processing ticker: KXRTMINECRAFT-5
# [market:KXRTMINECRAFT-5] Fetching trades...
# [market:KXRTMINECRAFT-5] Got 24 trades.
# [market:KXRTMINECRAFT-5] Wrote 24 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMINECRAFT-5.csv
# ============================================================
# Processing ticker: KXRTMINECRAFT-90
# [market:KXRTMINECRAFT-90] Fetching trades...
# [market:KXRTMINECRAFT-90] Got 13 trades.
# [market:KXRTMINECRAFT-90] Wrote 13 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMINECRAFT-90.csv
# ============================================================
# Processing ticker: KXRTMINECRAFT-85
# [market:KXRTMINECRAFT-85] Fetching trades...
# [market:KXRTMINECRAFT-85] Got 15 trades.
# [market:KXRTMINECRAFT-85] Wrote 15 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMINECRAFT-85.csv
# ============================================================
# Processing ticker: KXRTMINECRAFT-80
# [market:KXRTMINECRAFT-80] Fetching trades...
# [market:KXRTMINECRAFT-80] Got 71 trades.
# [market:KXRTMINECRAFT-80] Wrote 71 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMINECRAFT-80.csv
# ============================================================
# Processing ticker: KXRTMINECRAFT-75
# [market:KXRTMINECRAFT-75] Fetching trades...
# [market:KXRTMINECRAFT-75] Got 142 trades.
# [market:KXRTMINECRAFT-75] Wrote 142 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMINECRAFT-75.csv
# ============================================================
# Processing ticker: KXRTMINECRAFT-70
# [market:KXRTMINECRAFT-70] Fetching trades...
# [market:KXRTMINECRAFT-70] Got 92 trades.
# [market:KXRTMINECRAFT-70] Wrote 92 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMINECRAFT-70.csv
# ============================================================
# Processing ticker: KXRTMINECRAFT-65
# [market:KXRTMINECRAFT-65] Fetching trades...
# [market:KXRTMINECRAFT-65] Got 221 trades.
# [market:KXRTMINECRAFT-65] Wrote 221 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMINECRAFT-65.csv
# ============================================================
# Processing ticker: KXRTMINECRAFT-60
# [market:KXRTMINECRAFT-60] Fetching trades...
# [market:KXRTMINECRAFT-60] Got 1263 trades.
# [market:KXRTMINECRAFT-60] Wrote 1263 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMINECRAFT-60.csv
# ============================================================
# Processing ticker: KXRTMINECRAFT-55
# [market:KXRTMINECRAFT-55] Fetching trades...
# [market:KXRTMINECRAFT-55] Got 1335 trades.
# [market:KXRTMINECRAFT-55] Wrote 1335 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMINECRAFT-55.csv
# ============================================================
# Processing ticker: KXRTMINECRAFT-50
# [market:KXRTMINECRAFT-50] Fetching trades...
# [market:KXRTMINECRAFT-50] Got 4092 trades.
# [market:KXRTMINECRAFT-50] Wrote 4092 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMINECRAFT-50.csv
# ============================================================
# Processing ticker: KXRTMINECRAFT-45
# [market:KXRTMINECRAFT-45] Fetching trades...
# [market:KXRTMINECRAFT-45] Got 3920 trades.
# [market:KXRTMINECRAFT-45] Wrote 3920 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTMINECRAFT-45.csv
# ============================================================
# Processing ticker: KXSONGSONCHARTTSWIFT2-25NOV01
# [market:KXSONGSONCHARTTSWIFT2-25NOV01] Fetching trades...
# [market:KXSONGSONCHARTTSWIFT2-25NOV01] Got 3263 trades.
# [market:KXSONGSONCHARTTSWIFT2-25NOV01] Wrote 3263 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXSONGSONCHARTTSWIFT2-25NOV01.csv
# ============================================================
# Processing ticker: KXSONGSONCHARTTSWIFT2-25OCT25
# [market:KXSONGSONCHARTTSWIFT2-25OCT25] Fetching trades...
# [market:KXSONGSONCHARTTSWIFT2-25OCT25] Got 1021 trades.
# [market:KXSONGSONCHARTTSWIFT2-25OCT25] Wrote 1021 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXSONGSONCHARTTSWIFT2-25OCT25.csv
# ============================================================
# Processing ticker: KXRTTHEMONKEY-78
# [market:KXRTTHEMONKEY-78] Fetching trades...
# [market:KXRTTHEMONKEY-78] Got 677 trades.
# [market:KXRTTHEMONKEY-78] Wrote 677 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTTHEMONKEY-78.csv
# ============================================================
# Processing ticker: KXRTTHEMONKEY-82
# [market:KXRTTHEMONKEY-82] Fetching trades...
# [market:KXRTTHEMONKEY-82] Got 587 trades.
# [market:KXRTTHEMONKEY-82] Wrote 587 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTTHEMONKEY-82.csv
# ============================================================
# Processing ticker: KXRTTHEMONKEY-70
# [market:KXRTTHEMONKEY-70] Fetching trades...
# [market:KXRTTHEMONKEY-70] Got 73 trades.
# [market:KXRTTHEMONKEY-70] Wrote 73 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTTHEMONKEY-70.csv
# ============================================================
# Processing ticker: KXRTTHEMONKEY-95
# [market:KXRTTHEMONKEY-95] Fetching trades...
# [market:KXRTTHEMONKEY-95] Got 27 trades.
# [market:KXRTTHEMONKEY-95] Wrote 27 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTTHEMONKEY-95.csv
# ============================================================
# Processing ticker: KXRTTHEMONKEY-85
# [market:KXRTTHEMONKEY-85] Fetching trades...
# [market:KXRTTHEMONKEY-85] Got 3593 trades.
# [market:KXRTTHEMONKEY-85] Wrote 3593 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTTHEMONKEY-85.csv
# ============================================================
# Processing ticker: KXRTTHEMONKEY-80
# [market:KXRTTHEMONKEY-80] Fetching trades...
# [market:KXRTTHEMONKEY-80] Got 5446 trades.
# [market:KXRTTHEMONKEY-80] Wrote 5446 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTTHEMONKEY-80.csv
# ============================================================
# Processing ticker: KXRTTHEMONKEY-90
# [market:KXRTTHEMONKEY-90] Fetching trades...
# [market:KXRTTHEMONKEY-90] Got 1151 trades.
# [market:KXRTTHEMONKEY-90] Wrote 1151 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTTHEMONKEY-90.csv
# ============================================================
# Processing ticker: KXRTTHEMONKEY-75
# [market:KXRTTHEMONKEY-75] Fetching trades...
# [market:KXRTTHEMONKEY-75] Got 3355 trades.
# [market:KXRTTHEMONKEY-75] Wrote 3355 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTTHEMONKEY-75.csv
# ============================================================
# Processing ticker: KXRTTHEMONKEY-60
# [market:KXRTTHEMONKEY-60] Fetching trades...
# [market:KXRTTHEMONKEY-60] Got 96 trades.
# [market:KXRTTHEMONKEY-60] Wrote 96 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTTHEMONKEY-60.csv
# ============================================================
# Processing ticker: KXRTTHEMONKEY-45
# [market:KXRTTHEMONKEY-45] Fetching trades...
# [market:KXRTTHEMONKEY-45] Got 42 trades.
# [market:KXRTTHEMONKEY-45] Wrote 42 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTTHEMONKEY-45.csv
# ============================================================
# Processing ticker: KXRTNOVOCAINE-72
# [market:KXRTNOVOCAINE-72] Fetching trades...
# [market:KXRTNOVOCAINE-72] Got 7 trades.
# [market:KXRTNOVOCAINE-72] Wrote 7 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTNOVOCAINE-72.csv
# ============================================================
# Processing ticker: KXRTNOVOCAINE-77
# [market:KXRTNOVOCAINE-77] Fetching trades...
# [market:KXRTNOVOCAINE-77] Got 675 trades.
# [market:KXRTNOVOCAINE-77] Wrote 675 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTNOVOCAINE-77.csv
# ============================================================
# Processing ticker: KXRTNOVOCAINE-87
# [market:KXRTNOVOCAINE-87] Fetching trades...
# [market:KXRTNOVOCAINE-87] Got 24 trades.
# [market:KXRTNOVOCAINE-87] Wrote 24 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTNOVOCAINE-87.csv
# ============================================================
# Processing ticker: KXRTNOVOCAINE-82
# [market:KXRTNOVOCAINE-82] Fetching trades...
# [market:KXRTNOVOCAINE-82] Got 816 trades.
# [market:KXRTNOVOCAINE-82] Wrote 816 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTNOVOCAINE-82.csv
# ============================================================
# Processing ticker: KXRTNOVOCAINE-85
# [market:KXRTNOVOCAINE-85] Fetching trades...
# [market:KXRTNOVOCAINE-85] Got 1456 trades.
# [market:KXRTNOVOCAINE-85] Wrote 1456 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTNOVOCAINE-85.csv
# ============================================================
# Processing ticker: KXRTNOVOCAINE-65
# [market:KXRTNOVOCAINE-65] Fetching trades...
# [market:KXRTNOVOCAINE-65] Got 57 trades.
# [market:KXRTNOVOCAINE-65] Wrote 57 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTNOVOCAINE-65.csv
# ============================================================
# Processing ticker: KXRTNOVOCAINE-80
# [market:KXRTNOVOCAINE-80] Fetching trades...
# [market:KXRTNOVOCAINE-80] Got 3801 trades.
# [market:KXRTNOVOCAINE-80] Wrote 3801 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTNOVOCAINE-80.csv
# ============================================================
# Processing ticker: KXRTNOVOCAINE-70
# [market:KXRTNOVOCAINE-70] Fetching trades...
# [market:KXRTNOVOCAINE-70] Got 632 trades.
# [market:KXRTNOVOCAINE-70] Wrote 632 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTNOVOCAINE-70.csv
# ============================================================
# Processing ticker: KXRTNOVOCAINE-90
# [market:KXRTNOVOCAINE-90] Fetching trades...
# [market:KXRTNOVOCAINE-90] Got 383 trades.
# [market:KXRTNOVOCAINE-90] Wrote 383 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTNOVOCAINE-90.csv
# ============================================================
# Processing ticker: KXRTNOVOCAINE-75
# [market:KXRTNOVOCAINE-75] Fetching trades...
# [market:KXRTNOVOCAINE-75] Got 3886 trades.
# [market:KXRTNOVOCAINE-75] Wrote 3886 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTNOVOCAINE-75.csv
# ============================================================
# Processing ticker: KXRTNOVOCAINE-60
# [market:KXRTNOVOCAINE-60] Fetching trades...
# [market:KXRTNOVOCAINE-60] Got 318 trades.
# [market:KXRTNOVOCAINE-60] Wrote 318 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTNOVOCAINE-60.csv
# ============================================================
# Processing ticker: KXRTNOVOCAINE-45
# [market:KXRTNOVOCAINE-45] Fetching trades...
# [market:KXRTNOVOCAINE-45] Got 284 trades.
# [market:KXRTNOVOCAINE-45] Wrote 284 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTNOVOCAINE-45.csv
# ============================================================
# Processing ticker: KXRTFANTASTICFOUR-95
# [market:KXRTFANTASTICFOUR-95] Fetching trades...
# [market:KXRTFANTASTICFOUR-95] Got 16 trades.
# [market:KXRTFANTASTICFOUR-95] Wrote 16 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTFANTASTICFOUR-95.csv
# ============================================================
# Processing ticker: KXRTFANTASTICFOUR-87
# [market:KXRTFANTASTICFOUR-87] Fetching trades...
# [market:KXRTFANTASTICFOUR-87] Got 2172 trades.
# [market:KXRTFANTASTICFOUR-87] Wrote 2172 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTFANTASTICFOUR-87.csv
# ============================================================
# Processing ticker: KXRTFANTASTICFOUR-82
# [market:KXRTFANTASTICFOUR-82] Fetching trades...
# [market:KXRTFANTASTICFOUR-82] Got 280 trades.
# [market:KXRTFANTASTICFOUR-82] Wrote 280 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTFANTASTICFOUR-82.csv
# ============================================================
# Processing ticker: KXRTFANTASTICFOUR-85
# [market:KXRTFANTASTICFOUR-85] Fetching trades...
# [market:KXRTFANTASTICFOUR-85] Got 2617 trades.
# [market:KXRTFANTASTICFOUR-85] Wrote 2617 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTFANTASTICFOUR-85.csv
# ============================================================
# Processing ticker: KXRTFANTASTICFOUR-80
# [market:KXRTFANTASTICFOUR-80] Fetching trades...
# [market:KXRTFANTASTICFOUR-80] Got 1188 trades.
# [market:KXRTFANTASTICFOUR-80] Wrote 1188 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTFANTASTICFOUR-80.csv
# ============================================================
# Processing ticker: KXRTFANTASTICFOUR-70
# [market:KXRTFANTASTICFOUR-70] Fetching trades...
# [market:KXRTFANTASTICFOUR-70] Got 95 trades.
# [market:KXRTFANTASTICFOUR-70] Wrote 95 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTFANTASTICFOUR-70.csv
# ============================================================
# Processing ticker: KXRTFANTASTICFOUR-65
# [market:KXRTFANTASTICFOUR-65] Fetching trades...
# [market:KXRTFANTASTICFOUR-65] Got 52 trades.
# [market:KXRTFANTASTICFOUR-65] Wrote 52 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTFANTASTICFOUR-65.csv
# ============================================================
# Processing ticker: KXRTFANTASTICFOUR-90
# [market:KXRTFANTASTICFOUR-90] Fetching trades...
# [market:KXRTFANTASTICFOUR-90] Got 1475 trades.
# [market:KXRTFANTASTICFOUR-90] Wrote 1475 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTFANTASTICFOUR-90.csv
# ============================================================
# Processing ticker: KXRTFANTASTICFOUR-75
# [market:KXRTFANTASTICFOUR-75] Fetching trades...
# [market:KXRTFANTASTICFOUR-75] Got 1425 trades.
# [market:KXRTFANTASTICFOUR-75] Wrote 1425 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTFANTASTICFOUR-75.csv
# ============================================================
# Processing ticker: KXRTFANTASTICFOUR-60
# [market:KXRTFANTASTICFOUR-60] Fetching trades...
# [market:KXRTFANTASTICFOUR-60] Got 328 trades.
# [market:KXRTFANTASTICFOUR-60] Wrote 328 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTFANTASTICFOUR-60.csv
# ============================================================
# Processing ticker: KXRTFANTASTICFOUR-45
# [market:KXRTFANTASTICFOUR-45] Fetching trades...
# [market:KXRTFANTASTICFOUR-45] Got 54 trades.
# [market:KXRTFANTASTICFOUR-45] Wrote 54 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXRTFANTASTICFOUR-45.csv
# ============================================================
# Processing ticker: KXSONGSONCHARTTSWIFT6-25OCT25
# [market:KXSONGSONCHARTTSWIFT6-25OCT25] Fetching trades...
# [market:KXSONGSONCHARTTSWIFT6-25OCT25] Got 1223 trades.
# [market:KXSONGSONCHARTTSWIFT6-25OCT25] Wrote 1223 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXSONGSONCHARTTSWIFT6-25OCT25.csv
# ============================================================
# Processing ticker: KXTRUMPPUTIN-25-PHEG
# [market:KXTRUMPPUTIN-25-PHEG] Fetching trades...
# [market:KXTRUMPPUTIN-25-PHEG] Got 2467 trades.
# [market:KXTRUMPPUTIN-25-PHEG] Wrote 2467 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXTRUMPPUTIN-25-PHEG.csv
# ============================================================
# Processing ticker: KXTRUMPPUTIN-25-KAR
# [market:KXTRUMPPUTIN-25-KAR] Fetching trades...
# [market:KXTRUMPPUTIN-25-KAR] Got 3011 trades.
# [market:KXTRUMPPUTIN-25-KAR] Wrote 3011 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXTRUMPPUTIN-25-KAR.csv
# ============================================================
# Processing ticker: KXTRUMPPUTIN-25-SCO
# [market:KXTRUMPPUTIN-25-SCO] Fetching trades...
# [market:KXTRUMPPUTIN-25-SCO] Got 1386 trades.
# [market:KXTRUMPPUTIN-25-SCO] Wrote 1386 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXTRUMPPUTIN-25-SCO.csv
# ============================================================
# Processing ticker: KXTRUMPPUTIN-25-STE
# [market:KXTRUMPPUTIN-25-STE] Fetching trades...
# [market:KXTRUMPPUTIN-25-STE] Got 442 trades.
# [market:KXTRUMPPUTIN-25-STE] Wrote 442 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXTRUMPPUTIN-25-STE.csv
# ============================================================
# Processing ticker: KXTRUMPPUTIN-25-VZEL
# [market:KXTRUMPPUTIN-25-VZEL] Fetching trades...
# [market:KXTRUMPPUTIN-25-VZEL] Got 229 trades.
# [market:KXTRUMPPUTIN-25-VZEL] Wrote 229 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXTRUMPPUTIN-25-VZEL.csv
# ============================================================
# Processing ticker: KXTRUMPPUTIN-25-TCAR
# [market:KXTRUMPPUTIN-25-TCAR] Fetching trades...
# [market:KXTRUMPPUTIN-25-TCAR] Got 28 trades.
# [market:KXTRUMPPUTIN-25-TCAR] Wrote 28 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXTRUMPPUTIN-25-TCAR.csv
# ============================================================
# Processing ticker: KXTRUMPPUTIN-25-LLOO
# [market:KXTRUMPPUTIN-25-LLOO] Fetching trades...
# [market:KXTRUMPPUTIN-25-LLOO] Got 21 trades.
# [market:KXTRUMPPUTIN-25-LLOO] Wrote 21 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXTRUMPPUTIN-25-LLOO.csv
# ============================================================
# Processing ticker: KXTRUMPPUTIN-25-KJON
# [market:KXTRUMPPUTIN-25-KJON] Fetching trades...
# [market:KXTRUMPPUTIN-25-KJON] Got 9 trades.
# [market:KXTRUMPPUTIN-25-KJON] Wrote 9 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXTRUMPPUTIN-25-KJON.csv
# ============================================================
# Processing ticker: KXTRUMPPUTIN-25-BNET
# [market:KXTRUMPPUTIN-25-BNET] Fetching trades...
# [market:KXTRUMPPUTIN-25-BNET] Got 5 trades.
# [market:KXTRUMPPUTIN-25-BNET] Wrote 5 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXTRUMPPUTIN-25-BNET.csv
# ============================================================
# Processing ticker: KXTRUMPPUTIN-25-SSWE
# [market:KXTRUMPPUTIN-25-SSWE] Fetching trades...
# [market:KXTRUMPPUTIN-25-SSWE] Got 16 trades.
# [market:KXTRUMPPUTIN-25-SSWE] Wrote 16 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXTRUMPPUTIN-25-SSWE.csv
# ============================================================
# Processing ticker: KXTRUMPPUTIN-25-MRUB
# [market:KXTRUMPPUTIN-25-MRUB] Fetching trades...
# [market:KXTRUMPPUTIN-25-MRUB] Got 474 trades.
# [market:KXTRUMPPUTIN-25-MRUB] Wrote 474 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXTRUMPPUTIN-25-MRUB.csv
# ============================================================
# Processing ticker: KXTRUMPPUTIN-25-LGRA
# [market:KXTRUMPPUTIN-25-LGRA] Fetching trades...
# [market:KXTRUMPPUTIN-25-LGRA] Got 65 trades.
# [market:KXTRUMPPUTIN-25-LGRA] Wrote 65 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXTRUMPPUTIN-25-LGRA.csv
# ============================================================
# Processing ticker: KXTRUMPPUTIN-25-JVAN
# [market:KXTRUMPPUTIN-25-JVAN] Fetching trades...
# [market:KXTRUMPPUTIN-25-JVAN] Got 4178 trades.
# [market:KXTRUMPPUTIN-25-JVAN] Wrote 4178 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXTRUMPPUTIN-25-JVAN.csv
# ============================================================
# Processing ticker: KXTRUMPPUTIN-25-DROD
# [market:KXTRUMPPUTIN-25-DROD] Fetching trades...
# [market:KXTRUMPPUTIN-25-DROD] Got 9 trades.
# [market:KXTRUMPPUTIN-25-DROD] Wrote 9 trades to c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXTRUMPPUTIN-25-DROD.csv
# Done fetching & saving trades for all tickers.

# %%
# Cell 13 — Load trades for one specific market: KXSBADS-25-CB

target_ticker = "KXSBADS-25-CB"

trades_path = TRADES_DIR / f"{target_ticker}.csv"
print("Trades path:", trades_path, "exists:", trades_path.exists())

market_trades_df = pd.read_csv(trades_path)

print("Rows:", len(market_trades_df))
market_trades_df.head()
# Out:
# Trades path: c:\Users\Adam Nhan\prediction-market-money-printer\data\series_trades\KXSBADS-25-CB.csv exists: True
# Rows: 4290
#                                trade_id         ticker  price  yes_price  \
# 0  c17edfc1-b778-4261-bf9b-d6517493dbb0  KXSBADS-25-CB   0.01          1
# 1  bafc053e-9981-455b-8ba7-4b80c5b39d52  KXSBADS-25-CB   0.01          1
# 2  85341570-95e0-464e-af4b-dcbdb5128cab  KXSBADS-25-CB   0.01          1
# 3  6147d800-5161-403c-8db7-f7ce980e3663  KXSBADS-25-CB   0.01          1
# 4  24d60d07-4377-4307-a2f7-b91d143710b4  KXSBADS-25-CB   0.01          1
#
#    no_price  yes_price_dollars  no_price_dollars  count taker_side  \
# 0        99               0.01              0.99   4193        yes
# 1        99               0.01              0.99   1000        yes
# 2        99               0.01              0.99    500        yes
# 3        99               0.01              0.99    100        yes
# 4        99               0.01              0.99    119        yes
#
#                   created_time
# 0  2025-02-10T03:20:57.509561Z
# 1  2025-02-10T03:20:16.115251Z
# 2  2025-02-10T03:20:16.115251Z
# 3  2025-02-10T03:20:16.115251Z
# 4  2025-02-10T03:20:16.115251Z

# %%
# Cell 14 — Clean & prepare trade data for delta-p analysis

df = market_trades_df.copy()

# 1. Convert created_time -> datetime (UTC)
df["created_time"] = pd.to_datetime(df["created_time"], errors="coerce", utc=True)

# 2. Sort by time
df = df.sort_values("created_time").reset_index(drop=True)

# 3. Create market-implied probability
# yes_price_dollars is already in [0,1]
df["p_mkt"] = df["yes_price_dollars"]

# Quick peek
df[["created_time", "p_mkt"]].head()
# Out:
#                       created_time  p_mkt
# 0 2025-02-04 02:20:41.675941+00:00   0.23
# 1 2025-02-04 02:21:07.879938+00:00   0.23
# 2 2025-02-04 02:21:31.994860+00:00   0.23
# 3 2025-02-04 02:38:46.296169+00:00   0.48
# 4 2025-02-04 02:38:46.296169+00:00   0.47

# %%
# Cell 15 — Compute delta-p (change in implied probability)

df["delta_p"] = df["p_mkt"].diff()   # current - previous

# Peek at first few rows with delta-p
df[["created_time", "p_mkt", "delta_p"]].head(10)
# Out:
#                       created_time  p_mkt  delta_p
# 0 2025-02-04 02:20:41.675941+00:00   0.23      NaN
# 1 2025-02-04 02:21:07.879938+00:00   0.23     0.00
# 2 2025-02-04 02:21:31.994860+00:00   0.23     0.00
# 3 2025-02-04 02:38:46.296169+00:00   0.48     0.25
# 4 2025-02-04 02:38:46.296169+00:00   0.47    -0.01
# 5 2025-02-04 02:40:10.183553+00:00   0.49     0.02
# 6 2025-02-04 02:40:10.183553+00:00   0.48    -0.01
# 7 2025-02-04 02:56:29.335976+00:00   0.40    -0.08
# 8 2025-02-04 02:57:02.113588+00:00   0.24    -0.16
# 9 2025-02-04 03:15:48.131815+00:00   0.48     0.24

# %%
# Cell 16 — Identify threshold-based Δp events

threshold = 0.05   # 5% move

df["trigger"] = df["delta_p"].abs() >= threshold

# Show only rows where a trigger fired
df[df["trigger"]][["created_time", "p_mkt", "delta_p"]].head(10)
# Out:
#                        created_time  p_mkt  delta_p
# 3  2025-02-04 02:38:46.296169+00:00   0.48     0.25
# 7  2025-02-04 02:56:29.335976+00:00   0.40    -0.08
# 8  2025-02-04 02:57:02.113588+00:00   0.24    -0.16
# 9  2025-02-04 03:15:48.131815+00:00   0.48     0.24
# 25 2025-02-04 05:51:55.912252+00:00   0.60     0.11
# 27 2025-02-04 05:51:55.912252+00:00   0.51    -0.09
# 28 2025-02-04 05:53:32.486452+00:00   0.60     0.09
# 33 2025-02-04 06:24:37.757773+00:00   0.65     0.05
# 34 2025-02-04 06:24:37.757773+00:00   0.60    -0.05
# 39 2025-02-04 13:45:12.474238+00:00   0.40    -0.14

# %%
df["trigger"].sum()
# Out:
# np.int64(393)

# %%
# Cell 17 — Direction of the momentum signal

# +1 if delta_p > 0 (up move → YES), -1 if delta_p < 0 (down move → NO), 0 otherwise
df["signal_side"] = 0
df.loc[df["delta_p"] > 0, "signal_side"] = 1    # YES
df.loc[df["delta_p"] < 0, "signal_side"] = -1   # NO

# Filter to only trigger rows, show a small sample
signal_rows = df[df["trigger"]][["created_time", "p_mkt", "delta_p", "signal_side"]]
signal_rows.head(10)
# Out:
#                        created_time  p_mkt  delta_p  signal_side
# 3  2025-02-04 02:38:46.296169+00:00   0.48     0.25            1
# 7  2025-02-04 02:56:29.335976+00:00   0.40    -0.08           -1
# 8  2025-02-04 02:57:02.113588+00:00   0.24    -0.16           -1
# 9  2025-02-04 03:15:48.131815+00:00   0.48     0.24            1
# 25 2025-02-04 05:51:55.912252+00:00   0.60     0.11            1
# 27 2025-02-04 05:51:55.912252+00:00   0.51    -0.09           -1
# 28 2025-02-04 05:53:32.486452+00:00   0.60     0.09            1
# 33 2025-02-04 06:24:37.757773+00:00   0.65     0.05            1
# 34 2025-02-04 06:24:37.757773+00:00   0.60    -0.05           -1
# 39 2025-02-04 13:45:12.474238+00:00   0.40    -0.14           -1

# %%
# Cell 18 — Use a stricter Δp threshold of 0.25

threshold = 0.4

df["trigger_025"] = df["delta_p"].abs() >= threshold
df["side_025"] = 0
df.loc[df["delta_p"] > 0, "side_025"] = 1
df.loc[df["delta_p"] < 0, "side_025"] = -1

print("Number of 0.25 triggers:", df["trigger_025"].sum())

# Show first few triggers
df[df["trigger_025"]][["created_time", "p_mkt", "delta_p", "side_025"]].head(10)
# Out:
# Number of 0.25 triggers: 1
#                          created_time  p_mkt  delta_p  side_025
# 3561 2025-02-10 00:10:43.217835+00:00   0.66     0.47         1

# %%
# Cell 19 — Identify the first Δp ≥ 0.25 event as the entry

# Get only rows where the 0.25 trigger fired
trig = df[df["trigger_025"]].copy()

print("Total 0.25 triggers:", len(trig))

if len(trig) == 0:
    print("No 0.25 triggers in this market.")
    first_entry = None
else:
    # First trigger in time
    first_entry = trig.iloc[0]

    entry_time = first_entry["created_time"]
    entry_price = first_entry["p_mkt"]       # implied prob at entry
    entry_side = first_entry["side_025"]     # +1 = YES, -1 = NO
    entry_delta = first_entry["delta_p"]

    print("First entry candidate:")
    print(" time :", entry_time)
    print(" p_mkt:", entry_price)
    print(" side :", "YES" if entry_side > 0 else "NO")
    print(" Δp   :", entry_delta)
# Out:
# Total 0.25 triggers: 1
# First entry candidate:
#  time : 2025-02-10 00:10:43.217835+00:00
#  p_mkt: 0.66
#  side : YES
#  Δp   : 0.47000000000000003

# %%
# Cell 20 — Compute PnL for the single 0.25-threshold trade on this market

if first_entry is None:
    print("No 0.25 trigger → no trade → no PnL to compute.")
else:
    # 1. Look up this market in the metadata table
    meta_row = series_markets_df.loc[
        series_markets_df["market_ticker"] == target_ticker
    ]

    if meta_row.empty:
        raise ValueError(f"No metadata found for {target_ticker}")

    meta_row = meta_row.iloc[0]
    result_str = str(meta_row["result"]).lower()  # "yes" or "no"

    # 2. Convert to payoff for YES
    if result_str == "yes":
        payoff_yes = 1.0
    elif result_str == "no":
        payoff_yes = 0.0
    else:
        raise ValueError(f"Unexpected result value: {result_str}")

    # 3. Reuse entry info
    entry_price_yes = float(entry_price)      # p_mkt at entry (YES price in dollars)
    entry_side = int(entry_side)              # +1 YES, -1 NO

    # Prices for YES / NO
    price_yes = entry_price_yes
    price_no = 1.0 - entry_price_yes

    # Payoff depending on side
    if entry_side > 0:   # long YES
        payoff = payoff_yes
        entry_cost = price_yes
    else:                # long NO
        payoff = 1.0 - payoff_yes
        entry_cost = price_no

    pnl = payoff - entry_cost

    print(f"Market: {target_ticker}")
    print(f"Result: {result_str.upper()}  (payoff_yes={payoff_yes})")
    print(f"Entry side: {'YES' if entry_side>0 else 'NO'}")
    print(f"Entry price (YES): {entry_price_yes:.4f}")
    print(f"Effective entry cost: {entry_cost:.4f}")
    print(f"Payoff on position: {payoff:.4f}")
    print(f"PnL (no fees yet): {pnl:.4f}")
# Out:
# Market: KXSBADS-25-CB
# Result: NO  (payoff_yes=0.0)
# Entry side: YES
# Entry price (YES): 0.6600
# Effective entry cost: 0.6600
# Payoff on position: 0.0000
# PnL (no fees yet): -0.6600

# %%
# Cell 21 — Backtest a single market at a single Δp threshold

def backtest_single_market_threshold(
    ticker: str,
    threshold: float = 0.25,
    verbose: bool = False,
):
    """
    For a given market ticker:
      - load trades
      - compute delta-p
      - find FIRST |Δp| >= threshold
      - determine side (YES/NO)
      - look up final result
      - compute PnL (no fees yet)

    Returns a dict with summary info, or None if no trade.
    """
    # 1. Load trades CSV
    path = TRADES_DIR / f"{ticker}.csv"
    if not path.exists():
        if verbose:
            print(f"[{ticker}] No trades file at {path}")
        return None

    trades_df = pd.read_csv(path)
    if trades_df.empty:
        if verbose:
            print(f"[{ticker}] Trades file is empty.")
        return None

    # 2. Prepare data
    df = trades_df.copy()
    df["created_time"] = pd.to_datetime(df["created_time"], errors="coerce", utc=True)
    df = df.sort_values("created_time").reset_index(drop=True)
    df["p_mkt"] = df["yes_price_dollars"]
    df["delta_p"] = df["p_mkt"].diff()

    # 3. Find trigger rows
    df["trigger"] = df["delta_p"].abs() >= threshold
    df["side"] = 0
    df.loc[df["delta_p"] > 0, "side"] = 1    # YES
    df.loc[df["delta_p"] < 0, "side"] = -1   # NO

    trig = df[df["trigger"]]
    if trig.empty:
        if verbose:
            print(f"[{ticker}] No |Δp| >= {threshold:.2f} trigger → no trade.")
        return {
            "market_ticker": ticker,
            "threshold": threshold,
            "had_trade": False,
            "entry_time": None,
            "entry_side": None,
            "entry_price_yes": None,
            "pnl": 0.0,
            "result": None,
        }

    # 4. Take first trigger
    first = trig.iloc[0]
    entry_time = first["created_time"]
    entry_price_yes = float(first["p_mkt"])
    entry_side = int(first["side"])  # +1 YES, -1 NO

    # 5. Look up metadata / result
    meta_row = series_markets_df.loc[
        series_markets_df["market_ticker"] == ticker
    ]
    if meta_row.empty:
        raise ValueError(f"No metadata found for {ticker}")
    meta_row = meta_row.iloc[0]
    result_str = str(meta_row["result"]).lower()  # "yes" / "no"

    if result_str == "yes":
        payoff_yes = 1.0
    elif result_str == "no":
        payoff_yes = 0.0
    else:
        raise ValueError(f"Unexpected result value for {ticker}: {result_str}")

    # 6. Compute payoff & PnL
    price_yes = entry_price_yes
    price_no = 1.0 - entry_price_yes

    if entry_side > 0:      # long YES
        payoff = payoff_yes
        entry_cost = price_yes
    else:                   # long NO
        payoff = 1.0 - payoff_yes
        entry_cost = price_no

    pnl = payoff - entry_cost

    if verbose:
        print(f"[{ticker}] threshold={threshold:.2f}")
        print(f"  result      : {result_str.upper()} (payoff_yes={payoff_yes})")
        print(f"  entry_time  : {entry_time}")
        print(f"  entry_side  : {'YES' if entry_side>0 else 'NO'}")
        print(f"  entry_price : {entry_price_yes:.4f}")
        print(f"  entry_cost  : {entry_cost:.4f}")
        print(f"  payoff      : {payoff:.4f}")
        print(f"  pnl         : {pnl:.4f}")

    return {
        "market_ticker": ticker,
        "threshold": threshold,
        "had_trade": True,
        "entry_time": entry_time,
        "entry_side": entry_side,
        "entry_price_yes": entry_price_yes,
        "pnl": pnl,
        "result": result_str,
    }

# %%
# Cell 22 — Test the single-market backtest function on a few tickers

test_tickers = unique_tickers[:3]  # first three markets
test_tickers
# Out:
# array(['KXSBADS-25-CB', 'KXSBADS-25-T', 'KXSBADS-25-PE'], dtype=object)

# %%
results_samples = []

for t in test_tickers:
    print("=" * 50)
    print("Testing:", t)
    res = backtest_single_market_threshold(t, threshold=0.25, verbose=True)
    results_samples.append(res)

results_samples
# Out:
# ==================================================
# Testing: KXSBADS-25-CB
# [KXSBADS-25-CB] threshold=0.25
#   result      : NO (payoff_yes=0.0)
#   entry_time  : 2025-02-10 00:10:43.217835+00:00
#   entry_side  : YES
#   entry_price : 0.6600
#   entry_cost  : 0.6600
#   payoff      : 0.0000
#   pnl         : -0.6600
# ==================================================
# Testing: KXSBADS-25-T
# [KXSBADS-25-T] threshold=0.25
#   result      : NO (payoff_yes=0.0)
#   entry_time  : 2025-02-06 03:20:44.005234+00:00
#   entry_side  : YES
#   entry_price : 0.5700
#   entry_cost  : 0.5700
#   payoff      : 0.0000
#   pnl         : -0.5700
# ==================================================
# Testing: KXSBADS-25-PE
# [KXSBADS-25-PE] threshold=0.25
#   result      : YES (payoff_yes=1.0)
#   entry_time  : 2025-01-25 23:35:09.903742+00:00
#   entry_side  : YES
#   entry_price : 0.9500
#   entry_cost  : 0.9500
#   payoff      : 1.0000
#   pnl         : 0.0500
# [{'market_ticker': 'KXSBADS-25-CB',
#   'threshold': 0.25,
#   'had_trade': True,
#   'entry_time': Timestamp('2025-02-10 00:10:43.217835+0000', tz='UTC'),
#   'entry_side': 1,
#   'entry_price_yes': 0.66,
#   'pnl': -0.66,
#   'result': 'no'},
#  {'market_ticker': 'KXSBADS-25-T',
#   'threshold': 0.25,
#   'had_trade': True,
#   'entry_time': Timestamp('2025-02-06 03:20:44.005234+0000', tz='UTC'),
#   'entry_side': 1,
#   'entry_price_yes': 0.57,
#   'pnl': -0.57,
#   'result': 'no'},
#  {'market_ticker': 'KXSBADS-25-PE',
#   'threshold': 0.25,
#   'had_trade': True,
#   'entry_time': Timestamp('2025-01-25 23:35:09.903742+0000', tz='UTC'),
#   'entry_side': 1,
#   'entry_price_yes': 0.95,
#   'pnl': 0.050000000000000044,
#   'result': 'yes'}]

# %%
# Cell 23 — Backtest ALL markets at Δp threshold = 0.25

threshold = 0.4

all_results = []

for t in unique_tickers:
    res = backtest_single_market_threshold(t, threshold=threshold, verbose=False)
    if res is None:
        # e.g. missing file — you can also log/print here if you want
        continue
    all_results.append(res)

len(all_results)
# Out:
# 168

# %%
# Cell 24 — Results DataFrame + basic stats

results_df = pd.DataFrame(all_results)
print("Rows in results_df:", len(results_df))
results_df.head()
# Out:
# Rows in results_df: 168
#    market_ticker  threshold  had_trade                       entry_time  \
# 0  KXSBADS-25-CB        0.4       True 2025-02-10 00:10:43.217835+00:00
# 1   KXSBADS-25-T        0.4      False                              NaT
# 2  KXSBADS-25-PE        0.4      False                              NaT
# 3  KXSBADS-25-CC        0.4       True 2025-01-31 16:35:08.905157+00:00
# 4   KXSBADS-25-H        0.4       True 2025-02-10 01:22:34.775518+00:00
#
#    entry_side  entry_price_yes   pnl result
# 0         1.0             0.66 -0.66     no
# 1         NaN              NaN  0.00   None
# 2         NaN              NaN  0.00   None
# 3        -1.0             0.13  0.13     no
# 4         1.0             0.80 -0.80     no

# %%
# How many markets had an actual trade?
results_df["had_trade"].value_counts()
# Out:
# had_trade
# False    135
# True      33
# Name: count, dtype: int64

# %%
# PnL stats for markets where we actually traded
trade_pnls = results_df[results_df["had_trade"]]["pnl"]

summary = {
    "num_markets": len(results_df),
    "num_trades": len(trade_pnls),
    "mean_pnl": trade_pnls.mean(),
    "median_pnl": trade_pnls.median(),
    "min_pnl": trade_pnls.min(),
    "max_pnl": trade_pnls.max(),
}
summary
# Out:
# {'num_markets': 168,
#  'num_trades': 33,
#  'mean_pnl': np.float64(-0.3721212121212121),
#  'median_pnl': -0.66,
#  'min_pnl': -0.99,
#  'max_pnl': 0.55}

# %%
# Cell 25 — Backtest all markets across multiple Δp thresholds

thresholds = [0.05, 0.08, 0.10, 0.12, 0.15, 0.20, 0.25]

all_results_multi = []

for thr in thresholds:
    print("=" * 70)
    print(f"Running backtest for threshold = {thr:.2f}")
    
    for t in unique_tickers:
        res = backtest_single_market_threshold(
            t,
            threshold=thr,
            verbose=False,
        )
        if res is None:
            continue
        all_results_multi.append(res)

len(all_results_multi)
# Out:
# ======================================================================
# Running backtest for threshold = 0.05
# ======================================================================
# Running backtest for threshold = 0.08
# ======================================================================
# Running backtest for threshold = 0.10
# ======================================================================
# Running backtest for threshold = 0.12
# ======================================================================
# Running backtest for threshold = 0.15
# ======================================================================
# Running backtest for threshold = 0.20
# ======================================================================
# Running backtest for threshold = 0.25
# 1176

# %%
# Cell 26 — Build DataFrame and summarize by threshold

multi_df = pd.DataFrame(all_results_multi)
print("Rows in multi_df:", len(multi_df))
multi_df.head()
# Out:
# Rows in multi_df: 1176
#    market_ticker  threshold  had_trade                       entry_time  \
# 0  KXSBADS-25-CB       0.05       True 2025-02-04 02:38:46.296169+00:00
# 1   KXSBADS-25-T       0.05       True 2025-01-25 21:34:36.985058+00:00
# 2  KXSBADS-25-PE       0.05       True 2025-01-25 23:35:09.903742+00:00
# 3  KXSBADS-25-CC       0.05       True 2025-01-26 02:12:30.923499+00:00
# 4   KXSBADS-25-H       0.05       True 2025-01-25 22:17:42.142293+00:00
#
#    entry_side  entry_price_yes   pnl result
# 0         1.0             0.48 -0.48     no
# 1        -1.0             0.25  0.25     no
# 2         1.0             0.95  0.05    yes
# 3        -1.0             0.70  0.70     no
# 4        -1.0             0.25  0.25     no

# %%
# Keep only rows where a trade actually happened
trades_only = multi_df[multi_df["had_trade"]]

summary_rows = []

for thr in thresholds:
    sub = trades_only[trades_only["threshold"] == thr]
    pnls = sub["pnl"]
    
    summary_rows.append({
        "threshold": thr,
        "num_markets": sub["market_ticker"].nunique(),
        "num_trades": len(sub),
        "mean_pnl": pnls.mean() if len(pnls) > 0 else None,
        "median_pnl": pnls.median() if len(pnls) > 0 else None,
        "min_pnl": pnls.min() if len(pnls) > 0 else None,
        "max_pnl": pnls.max() if len(pnls) > 0 else None,
    })

threshold_summary_df = pd.DataFrame(summary_rows)
threshold_summary_df
# Out:
#    threshold  num_markets  num_trades  mean_pnl  median_pnl  min_pnl  max_pnl
# 0       0.05          140         140 -0.017929       0.055    -0.97     0.86
# 1       0.08          129         129 -0.019690       0.050    -0.97     0.86
# 2       0.10          121         121 -0.042149       0.010    -0.97     0.86
# 3       0.12          114         114 -0.051754       0.015    -0.99     0.86
# 4       0.15          104         104 -0.035192       0.055    -0.99     0.79
# 5       0.20           86          86 -0.186977      -0.290    -0.99     0.77
# 6       0.25           67          67 -0.238060      -0.360    -0.99     0.55

# %%
# Cell 27 — Always-short-from-open backtest for a single market

def backtest_open_short_no(ticker: str, verbose: bool = False):
    """
    Strategy:
      - At the first trade in the market, short YES (i.e. go long NO).
      - Hold to settlement.
    """
    # 1. Load trades
    path = TRADES_DIR / f"{ticker}.csv"
    if not path.exists():
        if verbose:
            print(f"[{ticker}] Trades file does not exist at {path}")
        return None
    
    trades_df = pd.read_csv(path)
    if trades_df.empty:
        if verbose:
            print(f"[{ticker}] Trades file is empty.")
        return None

    # 2. Get earliest trade
    df = trades_df.copy()
    df["created_time"] = pd.to_datetime(df["created_time"], errors="coerce", utc=True)
    df = df.sort_values("created_time").reset_index(drop=True)
    first = df.iloc[0]

    entry_time = first["created_time"]
    entry_price_yes = float(first["yes_price_dollars"])  # in [0,1]

    # 3. Look up result from metadata
    meta_row = series_markets_df.loc[
        series_markets_df["market_ticker"] == ticker
    ]
    if meta_row.empty:
        raise ValueError(f"No metadata found for {ticker}")
    meta_row = meta_row.iloc[0]
    result_str = str(meta_row["result"]).lower()  # "yes" or "no"

    if result_str == "yes":
        payoff_yes = 1.0
    elif result_str == "no":
        payoff_yes = 0.0
    else:
        raise ValueError(f"Unexpected result value for {ticker}: {result_str}")

    # 4. Position is long NO (short YES)
    price_yes = entry_price_yes
    price_no = 1.0 - entry_price_yes

    payoff_no = 1.0 - payoff_yes
    entry_cost_no = price_no

    pnl = payoff_no - entry_cost_no

    if verbose:
        print(f"[{ticker}] Open-short-NO strategy")
        print(f"  result        : {result_str.upper()} (payoff_yes={payoff_yes})")
        print(f"  entry_time    : {entry_time}")
        print(f"  entry_price_Y : {entry_price_yes:.4f}")
        print(f"  entry_cost_NO : {entry_cost_no:.4f}")
        print(f"  payoff_NO     : {payoff_no:.4f}")
        print(f"  pnl           : {pnl:.4f}")

    return {
        "market_ticker": ticker,
        "strategy": "open_short_no",
        "entry_time": entry_time,
        "entry_price_yes": entry_price_yes,
        "entry_cost_no": entry_cost_no,
        "result": result_str,
        "pnl": pnl,
    }

# %%
# Cell 28 — Test open-short-NO on one market

target_ticker = "KXSBADS-25-CB"

open_short_result = backtest_open_short_no(target_ticker, verbose=True)
open_short_result
# Out:
# [KXSBADS-25-CB] Open-short-NO strategy
#   result        : NO (payoff_yes=0.0)
#   entry_time    : 2025-02-04 02:20:41.675941+00:00
#   entry_price_Y : 0.2300
#   entry_cost_NO : 0.7700
#   payoff_NO     : 1.0000
#   pnl           : 0.2300
# {'market_ticker': 'KXSBADS-25-CB',
#  'strategy': 'open_short_no',
#  'entry_time': Timestamp('2025-02-04 02:20:41.675941+0000', tz='UTC'),
#  'entry_price_yes': 0.23,
#  'entry_cost_no': 0.77,
#  'result': 'no',
#  'pnl': 0.22999999999999998}

# %%
# Cell 29 — Backtest open-short-NO on ALL markets

open_short_results = []

for t in unique_tickers:
    res = backtest_open_short_no(t, verbose=False)
    if res is None:
        continue
    open_short_results.append(res)

len(open_short_results)
# Out:
# 168

# %%
# Cell 30 — DataFrame + stats for open-short-NO strategy

open_short_df = pd.DataFrame(open_short_results)
print("Rows in open_short_df:", len(open_short_df))
open_short_df.head()
# Out:
# Rows in open_short_df: 168
#    market_ticker       strategy                       entry_time  \
# 0  KXSBADS-25-CB  open_short_no 2025-02-04 02:20:41.675941+00:00
# 1   KXSBADS-25-T  open_short_no 2025-01-25 21:34:36.985058+00:00
# 2  KXSBADS-25-PE  open_short_no 2025-01-25 22:33:56.175338+00:00
# 3  KXSBADS-25-CC  open_short_no 2025-01-26 00:58:01.562666+00:00
# 4   KXSBADS-25-H  open_short_no 2025-01-25 21:43:24.025139+00:00
#
#    entry_price_yes  entry_cost_no result   pnl
# 0             0.23           0.77     no  0.23
# 1             0.33           0.67     no  0.33
# 2             0.69           0.31    yes -0.31
# 3             0.89           0.11     no  0.89
# 4             0.33           0.67     no  0.33

# %%
# PnL stats
pnls = open_short_df["pnl"]

open_short_summary = {
    "num_markets": len(open_short_df),
    "mean_pnl": pnls.mean(),
    "median_pnl": pnls.median(),
    "min_pnl": pnls.min(),
    "max_pnl": pnls.max(),
}
open_short_summary
# Out:
# {'num_markets': 168,
#  'mean_pnl': np.float64(0.09125000000000001),
#  'median_pnl': 0.010000000000000009,
#  'min_pnl': -0.99,
#  'max_pnl': 0.99}

# %%
# StrategyConfig-driven backtest helpers
import itertools
import json
from dataclasses import asdict
from datetime import timedelta

sys.path.append(str(PROJECT_ROOT))
from trading_engine.strategy_config import StrategyConfig

# %%
# Helpers: load trades, simulate NO position, summarize backtest

def load_trades_with_result(ticker: str):
    df_path = TRADES_DIR / f"{ticker}.csv"
    if not df_path.exists():
        return None, None

    df = pd.read_csv(df_path)
    if df.empty:
        return None, None

    df["created_time"] = pd.to_datetime(df["created_time"], errors="coerce", utc=True)
    df = df.sort_values("created_time").reset_index(drop=True)
    df["price_yes"] = df["yes_price_dollars"]
    df["price_no"] = 1.0 - df["price_yes"]

    meta_row = series_markets_df.loc[series_markets_df["market_ticker"] == ticker]
    if meta_row.empty:
        return df, None

    result_str = str(meta_row.iloc[0]["result"]).lower()
    return df, result_str


def simulate_no_position_with_config(ticker: str, cfg: StrategyConfig, qty: int = 1, verbose: bool = False):
    trades_df, result_str = load_trades_with_result(ticker)
    if trades_df is None:
        if verbose:
            print(f"[{ticker}] no trades loaded")
        return {
            "market_ticker": ticker,
            "had_trade": False,
            "pnl": 0.0,
            "exit_reason": "no_trades",
            "entry_time": None,
            "exit_time": None,
        }

    payoff_yes = None
    if result_str == "yes":
        payoff_yes = 1.0
    elif result_str == "no":
        payoff_yes = 0.0

    candidates = trades_df
    if cfg.max_no_entry_price is not None:
        candidates = candidates[candidates["price_no"] <= cfg.max_no_entry_price]

    if candidates.empty:
        if verbose:
            print(f"[{ticker}] skipped: no price_no <= {cfg.max_no_entry_price}")
        return {
            "market_ticker": ticker,
            "had_trade": False,
            "pnl": 0.0,
            "exit_reason": "entry_filtered",
            "entry_time": None,
            "exit_time": None,
        }

    entry = candidates.iloc[0]
    entry_time = entry["created_time"]
    entry_price_no = float(entry["price_no"])
    entry_value = entry_price_no * qty

    take_profit_val = None if cfg.take_profit_pct is None else cfg.take_profit_pct * entry_value
    stop_loss_val = None if cfg.stop_loss_pct is None else cfg.stop_loss_pct * entry_value

    exit_price_no = None
    exit_time = None
    exit_reason = None

    for _, row in trades_df[trades_df["created_time"] >= entry_time].iterrows():
        curr_no = float(row["price_no"])
        pnl_running = (entry_price_no - curr_no) * qty

        if take_profit_val is not None and pnl_running >= take_profit_val:
            exit_price_no = curr_no
            exit_time = row["created_time"]
            exit_reason = "take_profit"
            break

        if stop_loss_val is not None and pnl_running <= stop_loss_val:
            exit_price_no = curr_no
            exit_time = row["created_time"]
            exit_reason = "stop_loss"
            break

        if cfg.max_hold_seconds is not None:
            age = (row["created_time"] - entry_time).total_seconds()
            if age >= cfg.max_hold_seconds:
                exit_price_no = curr_no
                exit_time = row["created_time"]
                exit_reason = "time_expired"
                break

    if exit_price_no is None:
        payoff_no = (1.0 - payoff_yes) if payoff_yes is not None else float(trades_df.iloc[-1]["price_no"])
        exit_price_no = payoff_no
        exit_time = trades_df.iloc[-1]["created_time"]
        exit_reason = "settlement"

    final_pnl = (entry_price_no - exit_price_no) * qty

    return {
        "market_ticker": ticker,
        "had_trade": True,
        "pnl": final_pnl,
        "exit_reason": exit_reason,
        "entry_time": entry_time,
        "exit_time": exit_time,
        "entry_price_no": entry_price_no,
        "exit_price_no": exit_price_no,
        "result": result_str,
    }


def backtest_config_over_markets(cfg: StrategyConfig, tickers: list[str]) -> pd.DataFrame:
    rows = []
    for t in tickers:
        res = simulate_no_position_with_config(t, cfg)
        res["max_no_entry_price"] = cfg.max_no_entry_price
        res["take_profit_pct"] = cfg.take_profit_pct
        res["stop_loss_pct"] = cfg.stop_loss_pct
        res["max_hold_seconds"] = cfg.max_hold_seconds
        rows.append(res)
    return pd.DataFrame(rows)


def summarize_backtest(df: pd.DataFrame) -> dict[str, float]:
    trades = df[df["had_trade"]]
    if trades.empty:
        return {
            "num_markets": len(df),
            "num_trades": 0,
            "mean_pnl": 0.0,
            "median_pnl": 0.0,
            "min_pnl": 0.0,
            "max_pnl": 0.0,
            "win_rate": 0.0,
        }

    pnls = trades["pnl"]
    return {
        "num_markets": len(df),
        "num_trades": len(trades),
        "mean_pnl": pnls.mean(),
        "median_pnl": pnls.median(),
        "min_pnl": pnls.min(),
        "max_pnl": pnls.max(),
        "win_rate": (pnls > 0).mean(),
    }

# %%
# Grid search StrategyConfig space against historical trades
search_space = {
    "max_no_entry_price": [0.25, 0.35, 0.45, 0.55, 0.65, None],
    "take_profit_pct": [None, 0.05, 0.10, 0.20],
    "stop_loss_pct": [None, -0.05, -0.10, -0.20],
    "max_hold_seconds": [6 * 3600, 24 * 3600, 3 * 24 * 3600, None],
}

grid_rows = []
for max_no, tp, sl, hold in itertools.product(
    search_space["max_no_entry_price"],
    search_space["take_profit_pct"],
    search_space["stop_loss_pct"],
    search_space["max_hold_seconds"],
):
    cfg = StrategyConfig(
        max_no_entry_price=max_no,
        take_profit_pct=tp,
        stop_loss_pct=sl,
        max_hold_seconds=hold,
    )

    cfg_df = backtest_config_over_markets(cfg, unique_tickers)
    summary = summarize_backtest(cfg_df)
    summary.update({
        "max_no_entry_price": max_no,
        "take_profit_pct": tp,
        "stop_loss_pct": sl,
        "max_hold_seconds": hold,
    })
    grid_rows.append(summary)

grid_df = pd.DataFrame(grid_rows)

grid_df = grid_df.sort_values(["mean_pnl", "win_rate"], ascending=[False, False]).reset_index(drop=True)

grid_df.head()

# %%
# Extract best config, persist, and summarize
if grid_df.empty:
    raise ValueError("Grid search returned no configs")

best_row = grid_df.iloc[0].to_dict()

best_config = StrategyConfig(
    max_no_entry_price=best_row["max_no_entry_price"],
    take_profit_pct=best_row["take_profit_pct"],
    stop_loss_pct=best_row["stop_loss_pct"],
    max_hold_seconds=best_row["max_hold_seconds"],
)

best_config_df = backtest_config_over_markets(best_config, unique_tickers)
best_summary = summarize_backtest(best_config_df)

best_config_dict = asdict(best_config)
best_config_dict.update({
    "mean_pnl": best_summary["mean_pnl"],
    "win_rate": best_summary["win_rate"],
    "num_trades": best_summary["num_trades"],
})

best_config_path = DATA_DIR / "best_strategy_config.json"
best_config_path.write_text(json.dumps(best_config_dict, indent=2))
print("Saved best config to", best_config_path)

pd.DataFrame([best_summary])

# %%
#STRATEGY CONFIG

# %%
# StrategyConfig-driven backtest helpers
import itertools
import json
from dataclasses import asdict
from datetime import timedelta
import sys

sys.path.append(str(PROJECT_ROOT))
from trading_engine.strategy_config import StrategyConfig

# %%
# Helpers: load trades, simulate NO position, summarize backtest

def load_trades_with_result(ticker: str):
    df_path = TRADES_DIR / f"{ticker}.csv"
    if not df_path.exists():
        return None, None

    df = pd.read_csv(df_path)
    if df.empty:
        return None, None

    df["created_time"] = pd.to_datetime(df["created_time"], errors="coerce", utc=True)
    df = df.sort_values("created_time").reset_index(drop=True)
    df["price_yes"] = df["yes_price_dollars"]
    df["price_no"] = 1.0 - df["price_yes"]

    meta_row = series_markets_df.loc[series_markets_df["market_ticker"] == ticker]
    if meta_row.empty:
        return df, None

    result_str = str(meta_row.iloc[0]["result"]).lower()
    return df, result_str


def simulate_no_position_with_config(ticker: str, cfg: StrategyConfig, qty: int = 1, verbose: bool = False):
    trades_df, result_str = load_trades_with_result(ticker)
    if trades_df is None:
        if verbose:
            print(f"[{ticker}] no trades loaded")
        return {
            "market_ticker": ticker,
            "had_trade": False,
            "pnl": 0.0,
            "exit_reason": "no_trades",
            "entry_time": None,
            "exit_time": None,
        }

    payoff_yes = None
    if result_str == "yes":
        payoff_yes = 1.0
    elif result_str == "no":
        payoff_yes = 0.0

    candidates = trades_df
    if cfg.max_no_entry_price is not None:
        candidates = candidates[candidates["price_no"] <= cfg.max_no_entry_price]

    if candidates.empty:
        if verbose:
            print(f"[{ticker}] skipped: no price_no <= {cfg.max_no_entry_price}")
        return {
            "market_ticker": ticker,
            "had_trade": False,
            "pnl": 0.0,
            "exit_reason": "entry_filtered",
            "entry_time": None,
            "exit_time": None,
        }

    entry = candidates.iloc[0]
    entry_time = entry["created_time"]
    entry_price_no = float(entry["price_no"])
    entry_value = entry_price_no * qty

    take_profit_val = None if cfg.take_profit_pct is None else cfg.take_profit_pct * entry_value
    stop_loss_val = None if cfg.stop_loss_pct is None else cfg.stop_loss_pct * entry_value

    exit_price_no = None
    exit_time = None
    exit_reason = None

    for _, row in trades_df[trades_df["created_time"] >= entry_time].iterrows():
        curr_no = float(row["price_no"])
        pnl_running = (entry_price_no - curr_no) * qty

        if take_profit_val is not None and pnl_running >= take_profit_val:
            exit_price_no = curr_no
            exit_time = row["created_time"]
            exit_reason = "take_profit"
            break

        if stop_loss_val is not None and pnl_running <= stop_loss_val:
            exit_price_no = curr_no
            exit_time = row["created_time"]
            exit_reason = "stop_loss"
            break

        if cfg.max_hold_seconds is not None:
            age = (row["created_time"] - entry_time).total_seconds()
            if age >= cfg.max_hold_seconds:
                exit_price_no = curr_no
                exit_time = row["created_time"]
                exit_reason = "time_expired"
                break

    if exit_price_no is None:
        payoff_no = (1.0 - payoff_yes) if payoff_yes is not None else float(trades_df.iloc[-1]["price_no"])
        exit_price_no = payoff_no
        exit_time = trades_df.iloc[-1]["created_time"]
        exit_reason = "settlement"

    final_pnl = (entry_price_no - exit_price_no) * qty

    return {
        "market_ticker": ticker,
        "had_trade": True,
        "pnl": final_pnl,
        "exit_reason": exit_reason,
        "entry_time": entry_time,
        "exit_time": exit_time,
        "entry_price_no": entry_price_no,
        "exit_price_no": exit_price_no,
        "result": result_str,
    }


def backtest_config_over_markets(cfg: StrategyConfig, tickers: list[str]) -> pd.DataFrame:
    rows = []
    for t in tickers:
        res = simulate_no_position_with_config(t, cfg)
        res["max_no_entry_price"] = cfg.max_no_entry_price
        res["take_profit_pct"] = cfg.take_profit_pct
        res["stop_loss_pct"] = cfg.stop_loss_pct
        res["max_hold_seconds"] = cfg.max_hold_seconds
        rows.append(res)
    return pd.DataFrame(rows)


def summarize_backtest(df: pd.DataFrame) -> dict[str, float]:
    trades = df[df["had_trade"]]
    if trades.empty:
        return {
            "num_markets": len(df),
            "num_trades": 0,
            "mean_pnl": 0.0,
            "median_pnl": 0.0,
            "min_pnl": 0.0,
            "max_pnl": 0.0,
            "win_rate": 0.0,
        }

    pnls = trades["pnl"]
    return {
        "num_markets": len(df),
        "num_trades": len(trades),
        "mean_pnl": pnls.mean(),
        "median_pnl": pnls.median(),
        "min_pnl": pnls.min(),
        "max_pnl": pnls.max(),
        "win_rate": (pnls > 0).mean(),
    }

# %%
# Grid search StrategyConfig space against historical trades
search_space = {
    "max_no_entry_price": [0.25, 0.35, 0.45, 0.55, 0.65, None],
    "take_profit_pct": [None, 0.05, 0.10, 0.20],
    "stop_loss_pct": [None, -0.05, -0.10, -0.20],
    "max_hold_seconds": [6 * 3600, 24 * 3600, 3 * 24 * 3600, None],
}

grid_rows = []
for max_no, tp, sl, hold in itertools.product(
    search_space["max_no_entry_price"],
    search_space["take_profit_pct"],
    search_space["stop_loss_pct"],
    search_space["max_hold_seconds"],
):
    cfg = StrategyConfig(
        max_no_entry_price=max_no,
        take_profit_pct=tp,
        stop_loss_pct=sl,
        max_hold_seconds=hold,
    )

    cfg_df = backtest_config_over_markets(cfg, unique_tickers)
    summary = summarize_backtest(cfg_df)
    summary.update({
        "max_no_entry_price": max_no,
        "take_profit_pct": tp,
        "stop_loss_pct": sl,
        "max_hold_seconds": hold,
    })
    grid_rows.append(summary)

grid_df = pd.DataFrame(grid_rows)
grid_df = grid_df.sort_values(["mean_pnl", "win_rate"], ascending=[False, False]).reset_index(drop=True)

grid_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 23
#      10 for max_no, tp, sl, hold in itertools.product(
#      11     search_space["max_no_entry_price"],
#      12     search_space["take_profit_pct"],
#      13     search_space["stop_loss_pct"],
#      14     search_space["max_hold_seconds"],
#      15 ):
#      16     cfg = StrategyConfig(
#      17         max_no_entry_price=max_no,
#      18         take_profit_pct=tp,
#      19         stop_loss_pct=sl,
#      20         max_hold_seconds=hold,
#      21     )
# ---> 23     cfg_df = backtest_config_over_markets(cfg, unique_tickers)
#      24     summary = summarize_backtest(cfg_df)
#      25     summary.update({
#      26         "max_no_entry_price": max_no,
#      27         "take_profit_pct": tp,
#      28         "stop_loss_pct": sl,
#      29         "max_hold_seconds": hold,
#      30     })
#
# NameError: name 'unique_tickers' is not defined
